# %% [markdown]
# ## Advanced Lane Finding Project
#
# The goals / steps of this project are the following:
#
# * Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.
# * Apply a distortion correction to raw images.
# * Use color transforms, gradients, etc., to create a thresholded binary image.
# * Apply a perspective transform to rectify binary image ("birds-eye view").
# * Detect lane pixels and fit to find the lane boundary.
# * Determine the curvature of the lane and vehicle position with respect to center.
# * Warp the detected lane boundaries back onto the original image.
# * Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.
#
# ---
# ## Compute the camera calibration using chessboard images

# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
#import PyQt4
#%matplotlib qt
# %matplotlib inline

# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((6*9,3), np.float32)
objp[:,:2] = np.mgrid[0:9,0:6].T.reshape(-1,2)

# Arrays to store object points and image points from all the images.
objpoints = [] # 3d points in real world space
imgpoints = [] # 2d points in image plane.

# Make a list of calibration images
images = glob.glob('camera_cal/calibration*.jpg')

# Step through the list and search for chessboard corners
for fname in images:
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        
    # Find the chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (9,6),None)

    # If found, add object points, image points
    if ret == True:
        objpoints.append(objp)
        imgpoints.append(corners)
            
        # Draw and display the corners
        img = cv2.drawChessboardCorners(img, (9,6), corners, ret)
        #cv2.imshow('img',img)
        #cv2.waitKey(500)
        plt.imshow(img)

#cv2.destroyAllWindows()

# %% [markdown]
# ## Undistort a camera image

# %%
name = glob.glob('test_images/test1.jpg')
img = cv2.imread(name[0])
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
def undistort(objpoints, imgpoints, img):

    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img.shape[:2], None, None)
    #images = glob.glob('test_images/test*.jpg')
    #dsta = []
    #for name in images:
    #img = cv2.imread(name)
    dst = cv2.undistort(img, mtx, dist, None, mtx)
    #dst = cv2.cvtColor(dst,cv2.COLOR_BGR2RGB)
    #dsta.append(dst)
    return dst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-36c1291a8818> in <module>()
#       1 name = glob.glob('test_images/test1.jpg')
# ----> 2 img = cv2.imread(name[0])
#       3 img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#       4 def undistort(objpoints, imgpoints, img):
#       5
#
# IndexError: list index out of range

# %%
undist_img = undistort(objpoints, imgpoints, img)
plt.imshow(undist_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-be0f81f1a08c> in <module>()
# ----> 1 undist_img = undistort(objpoints, imgpoints, img)
#       2 plt.imshow(undist_img)
#
# NameError: name 'undistort' is not defined

# %% [markdown]
# ## Create a threshold binary image

# %%
def binary_images(img):
    
    nimg = cv2.GaussianBlur(img,(3,3),3)
    img = cv2.cvtColor(nimg, cv2.COLOR_RGB2BGR)
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    V = hsv[:,:,2]
    sobelx = cv2.Sobel(V, cv2.CV_64F, 1, 0)
    abs_sobelx = np.absolute(sobelx)
    scaled_sobel = np.uint8(255*abs_sobelx/np.max(abs_sobelx))

    thresh_min = 10
    thresh_max = 225
    sxbinary = np.zeros_like(scaled_sobel)
    sxbinary[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1
    
    
    #nimg = cv2.GaussianBlur(img,(3,3),3)
    #gray = cv2.cvtColor(nimg, cv2.COLOR_RGB2GRAY)
    #sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0)
    #abs_sobelx = np.absolute(sobelx)
    #scaled_sobel = np.uint8(255*abs_sobelx/np.max(abs_sobelx))

    #thresh_min = 30
    #thresh_max = 225
    #sxbinary = np.zeros_like(scaled_sobel)
    #sxbinary[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1
    
    #hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    #s_channel = hls[:,:,2]
    #s_thresh_min = 170
    #s_thresh_max = 255
    #s_binary = np.zeros_like(s_channel)
    #s_binary[(s_channel >= s_thresh_min) & (s_channel <= s_thresh_max)] = 1
    
    #combined_binary = np.zeros_like(sxbinary)
    #combined_binary[(s_binary == 1) | (sxbinary == 1)] = 1
    
    return sxbinary

# %%
bina = binary_images(undist_img)
plt.imshow(bina, cmap='gray')

# %% [markdown]
# ## Perspective Transformation

# %%
def perspective_transform(img):
    
    #Mset = []
    #warpedset = []
    #Minvset = []
    
    #for img in imgs:
    src = np.float32([[200,700],[1250,700],[580,460],[750,460]])
    dst = np.float32([[200,700],[1280,700],[200,0],[1280,0]])
    img_size = (1280,720)

    M = cv2.getPerspectiveTransform(src,dst)
    warped = cv2.warpPerspective(img, M, img_size, flags=cv2.INTER_LINEAR)
    Minv = cv2.getPerspectiveTransform(dst,src)
    #img = cv2.GaussianBlur(warped,(3,3),3)
    nimg = cv2.medianBlur(warped,3,3)
    #Mset.append(M)
    #warpedset.append(warped)
    #Minvset.append(Minv)
    
    return M,Minv,nimg

# %%
M,Minv,warped = perspective_transform(bina)

# %%
plt.imshow(warped)

# %% [markdown]
# ## Finding Lanes

# %%
import matplotlib
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(15, 10)
#for im in bina:
im = warped[0]
histogram_upper = np.sum(warped[warped.shape[0]//2:,:],axis=0)
plt.plot(histogram_upper)
#histogram_lower = np.sum(warped[:warped.shape[0]//2,:],axis=0)
#plt.plot(histogram_lower)

# %%
leftprevious = []
rightprevious = []
leftinit = []
rightinit = []

def finding(warped):
    
    global leftprevious
    global rightprevious
    global leftinit
    global rightinit
    
    #for warped in images:
    histogram = np.sum(warped[warped.shape[0]//2:,:],axis=0)
    midpoint = histogram.shape[0]//2
    left = histogram[150:300]
    right = histogram[1100:1280]
        
    leftpoint = np.argmax(left)+150
    rightpoint = np.argmax(right)+1100
    #leftinit.append(leftpoint)
    #rightinit.append(rightpoint)
    #leftpoint = 200
    #rightpoint = 1150
    
    
    numwins = 9
    imgheight = warped.shape[0]
    imgwidth = warped.shape[1]
    winheight = imgheight//numwins
    winwidth = 100
    minpix = 50

    outimg = np.dstack((warped,warped,warped))*255
    nonzero = np.nonzero(warped)
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])

    leftcurrent = leftpoint
    rightcurrent = rightpoint

    leftlane = []
    rightlane = []
            
    for win in range(numwins):
        lowerbound = imgheight - (win+1)*winheight
        upperbound = imgheight - win*winheight
        lleftbound = leftcurrent - winwidth
        lrightbound = leftcurrent + winwidth
        rleftbound = rightcurrent - winwidth
        rrightbound = rightcurrent + winwidth
    
        cv2.rectangle(outimg,(lleftbound,lowerbound),(lrightbound,upperbound),(0,255,0),3)
        cv2.rectangle(outimg,(rleftbound,lowerbound),(rrightbound,upperbound),(0,255,0),3)
    
        leftinds = np.nonzero((nonzeroy >= lowerbound)&(nonzeroy < upperbound)&(nonzerox >= lleftbound)&(nonzerox < lrightbound))[0]
        rightinds = np.nonzero((nonzeroy >= lowerbound)&(nonzeroy < upperbound)&(nonzerox >= rleftbound)&(nonzerox < rrightbound))[0]
        leftlane.append(leftinds)
        rightlane.append(rightinds)
        
        if len(leftinds) > minpix:
            leftcurrent = np.int(np.mean(nonzerox[leftinds]))
        if len(rightinds) > minpix:
            rightcurrent = np.int(np.mean(nonzerox[rightinds]))
        
    leftinds = np.concatenate(leftlane)
    rightinds = np.concatenate(rightlane)
    leftx = nonzerox[leftinds]
    lefty = nonzeroy[leftinds]
    rightx = nonzerox[rightinds]
    righty = nonzeroy[rightinds]
    
    leftfitn = np.polyfit(lefty, leftx, 2)
    rightfitn = np.polyfit(righty, rightx, 2)
            
            
    leftprevious.append(leftfitn)
    rightprevious.append(rightfitn)
            
    if len(leftprevious) >= 20:
        leftfit = np.mean(leftprevious[-20:-1],axis=0)
        rightfit = np.mean(rightprevious[-20:-1],axis=0)
    else:
        leftfit = leftfitn
        rightfit = rightfitn

    ploty = np.linspace(0, warped.shape[0]-1, warped.shape[0])
    leftfitx = leftfit[0]*ploty**2+leftfit[1]*ploty**1+leftfit[2]#*ploty+leftfit[3]
    rightfitx = rightfit[0]*ploty**2+rightfit[1]*ploty**1+rightfit[2]#*ploty+rightfit[3]
    
    outimg[nonzeroy[leftinds],nonzerox[leftinds]] = [255,0,0]
    outimg[nonzeroy[rightinds],nonzerox[rightinds]] = [0,0,255]
    
    #plt.imshow(outimg)
    #plt.plot(leftfitx, ploty, color='yellow')
    #plt.plot(rightfitx, ploty, color='yellow')
    #plt.xlim(0,1280)
    #plt.ylim(720,0)
    
    return ploty,leftfit,rightfit,leftfitx,rightfitx,outimg

# %%
ploty,leftfit,rightfit,leftfitx,rightfitx,outimg = finding(warped)

# %%
plt.imshow(outimg)

# %% [markdown]
# ## Curvature and Position

# %%
def curvature_position(ploty,leftfit,rightfit,leftfitx,rightfitx):
    
    y_eval = np.max(ploty[:len(ploty)//2])
    left_curverad = ((1+(2*leftfit[0]*y_eval+leftfit[1])**2)**1.5)/np.absolute(2*leftfit[0])
    #print(leftfitx)
    right_curverad = ((1+(2*rightfit[0]*y_eval+rightfit[1])**2)**1.5)/np.absolute(2*rightfit[0])
    
    ym_per_pix = 30/720
    xm_per_pix = 3.7/700
    
    left_fit_cr = np.polyfit(ploty*ym_per_pix, leftfitx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(ploty*ym_per_pix, rightfitx*xm_per_pix, 2)
    
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
    
    #print(left_curverad, 'm', right_curverad, 'm')
    position = (640-(rightfitx[-1]+leftfitx[-1])/2)*xm_per_pix
    
    return left_curverad,right_curverad,position

# %%
left_curverad,right_curverad,position = curvature_position(ploty,leftfit,rightfit,leftfitx,rightfitx)

# %% [markdown]
# ## Warp Back

# %%
def warp_back(undist,warped,left_fitx,right_fitx,Minv):
    warp_zero = np.zeros_like(warped).astype(np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))
    
    pts_left = np.array([np.transpose(np.vstack([left_fitx, ploty]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ploty])))])
    pts = np.hstack((pts_left, pts_right))
    
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))
    newwarp = cv2.warpPerspective(color_warp, Minv, (warped.shape[1], warped.shape[0])) 
    result = cv2.addWeighted(undist, 1, newwarp, 0.3, 0)
    #plt.imshow(undist)
    #plt.imshow(result)
    return result

# %%
plt.imshow(undist_img)

# %%
warpback = warp_back(undist_img,warped,leftfitx,rightfitx,Minv)
result =cv2.putText(img=np.copy(warpback), text='{}{}{}'.format('radius of curve:', np.int(left_curverad), 'm'), org=(100,100),fontFace=2, fontScale=2, color=(255,255,255), thickness=3)
result =cv2.putText(img=np.copy(result), text='{}{}{}{}'.format('vehicle is ', round(position,2), 'm', ' left to the center'), org=(100,200),fontFace=2, fontScale=2, color=(255,255,255), thickness=3)
plt.imshow(result)

# %% [markdown]
# ## Visualize

# %%
def pipeline(image):
    global objpoints
    global imgpoints
    #image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    undist = undistort(objpoints,imgpoints,image)
    #plt.imshow(undist)
    binary = binary_images(undist)
    #plt.imshow(bianry)
    M,Minv,warped = perspective_transform(binary)
    ploty,leftfit,rightfit,leftfitx,rightfitx,outimg = finding(warped)
    left_curverad,right_curverad,position = curvature_position(ploty,leftfit,rightfit,leftfitx,rightfitx)
    warpback = warp_back(undist,warped,leftfitx,rightfitx,Minv)
    result =cv2.putText(img=warpback, text='{}{}{}'.format('radius of curve:', np.int(left_curverad), 'm'), org=(100,100),fontFace=2, fontScale=2, color=(255,255,255), thickness=3)
    nresult =cv2.putText(img=result, text='{}{}{}{}'.format('vehicle is ', round(position,2), 'm', ' left to the center'), org=(100,200),fontFace=2, fontScale=2, color=(255,255,255), thickness=3)
    #nnresult = cv2.cvtColor(nresult,cv2.COLOR_BGR2RGB)

    return nresult

# %%
plt.imshow(pipeline(undist_img))

# %%
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
white_output = 'project_video_ouput.mp4'
#white_output = 'project_video.mp4'

## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("project_video.mp4")
white_clip = clip1.fl_image(pipeline) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# [MoviePy] >>>> Building video project_video_ouput.mp4
# [MoviePy] Writing video project_video_ouput.mp4
#   0%|          | 0/1261 [00:00<?, ?it/s]
#
#
#
#
#   0%|          | 1/1261 [00:05<1:59:42,  5.70s/it]
#
#
#
#
#   0%|          | 2/1261 [00:11<1:59:21,  5.69s/it]
#
#
#
#
#   0%|          | 3/1261 [00:16<1:58:36,  5.66s/it]
#
#
#
#
#   0%|          | 4/1261 [00:22<1:57:42,  5.62s/it]
#
#
#
#
#   0%|          | 5/1261 [00:27<1:55:43,  5.53s/it]
#
#
#
#
#   0%|          | 6/1261 [00:33<1:54:28,  5.47s/it]
#
#
#
#
#   1%|          | 7/1261 [00:38<1:52:14,  5.37s/it]
#
#
#
#
#   1%|          | 8/1261 [00:43<1:51:57,  5.36s/it]
#
#
#
#
#   1%|          | 9/1261 [00:48<1:50:35,  5.30s/it]
#
#
#
#
#   1%|          | 10/1261 [00:53<1:49:30,  5.25s/it]
#
#
#
#
#   1%|          | 11/1261 [00:59<1:48:44,  5.22s/it]
#
#
#
#
#   1%|          | 12/1261 [01:04<1:48:09,  5.20s/it]
#
#
#
#
#   1%|          | 13/1261 [01:09<1:47:36,  5.17s/it]
#
#
#
#
#   1%|          | 14/1261 [01:14<1:50:37,  5.32s/it]
#
#
#
#
#   1%|          | 15/1261 [01:20<1:50:00,  5.30s/it]
#
#
#
#
#   1%|▏         | 16/1261 [01:25<1:49:13,  5.26s/it]
#
#
#
#
#   1%|▏         | 17/1261 [01:30<1:48:36,  5.24s/it]
#
#
#
#
#   1%|▏         | 18/1261 [01:35<1:48:10,  5.22s/it]
#
#
#
#
#   2%|▏         | 19/1261 [01:40<1:47:33,  5.20s/it]
#
#
#
#
#   2%|▏         | 20/1261 [01:46<1:47:35,  5.20s/it]
#
#
#
#
#   2%|▏         | 21/1261 [01:51<1:47:56,  5.22s/it]
#
#
#
#
#   2%|▏         | 22/1261 [01:56<1:47:23,  5.20s/it]
#
#
#
#
#   2%|▏         | 23/1261 [02:01<1:47:46,  5.22s/it]
#
#
#
#
#   2%|▏         | 24/1261 [02:06<1:47:10,  5.20s/it]
#
#
#
#
#   2%|▏         | 25/1261 [02:12<1:46:56,  5.19s/it]
#
#
#
#
#   2%|▏         | 26/1261 [02:17<1:46:41,  5.18s/it]
#
#
#
#
#   2%|▏         | 27/1261 [02:22<1:46:19,  5.17s/it]
#
#
#
#
#   2%|▏         | 28/1261 [02:27<1:46:51,  5.20s/it]
#
#
#
#
#   2%|▏         | 29/1261 [02:32<1:46:44,  5.20s/it]
#
#
#
#
#   2%|▏         | 30/1261 [02:38<1:46:34,  5.19s/it]
#
#
#
#
#   2%|▏         | 31/1261 [02:43<1:46:08,  5.18s/it]
#
#
#
#
#   3%|▎         | 32/1261 [02:48<1:48:39,  5.30s/it]
#
#
#
#
#   3%|▎         | 33/1261 [02:54<1:49:42,  5.36s/it]
#
#
#
#
#   3%|▎         | 34/1261 [02:59<1:50:13,  5.39s/it]
#
#
#
#
#   3%|▎         | 35/1261 [03:05<1:51:39,  5.46s/it]
#
#
#
#
#   3%|▎         | 36/1261 [03:10<1:51:21,  5.45s/it]
#
#
#
#
#   3%|▎         | 37/1261 [03:16<1:52:19,  5.51s/it]
#
#
#
#
#   3%|▎         | 38/1261 [03:21<1:50:07,  5.40s/it]
#
#
#
#
#   3%|▎         | 39/1261 [03:26<1:48:25,  5.32s/it]
#
#
#
#
#   3%|▎         | 40/1261 [03:31<1:47:09,  5.27s/it]
#
#
#
#
#   3%|▎         | 41/1261 [03:37<1:46:08,  5.22s/it]
#
#
#
#
#   3%|▎         | 42/1261 [03:42<1:45:33,  5.20s/it]
#
#
#
#
#   3%|▎         | 43/1261 [03:47<1:45:42,  5.21s/it]
#
#
#
#
#   3%|▎         | 44/1261 [03:52<1:45:32,  5.20s/it]
#
#
#
#
#   4%|▎         | 45/1261 [03:57<1:45:03,  5.18s/it]
#
#
#
#
#   4%|▎         | 46/1261 [04:02<1:44:39,  5.17s/it]
#
#
#
#
#   4%|▎         | 47/1261 [04:07<1:44:19,  5.16s/it]
#
#
#
#
#   4%|▍         | 48/1261 [04:13<1:44:01,  5.15s/it]
#
#
#
#
#   4%|▍         | 49/1261 [04:18<1:44:18,  5.16s/it]
#
#
#
#
#   4%|▍         | 50/1261 [04:23<1:44:11,  5.16s/it]
#
#
#
#
#   4%|▍         | 51/1261 [04:28<1:44:11,  5.17s/it]
#
#
#
#
#   4%|▍         | 52/1261 [04:33<1:44:12,  5.17s/it]
#
#
#
#
#   4%|▍         | 53/1261 [04:38<1:43:58,  5.16s/it]
#
#
#
#
#   4%|▍         | 54/1261 [04:44<1:43:47,  5.16s/it]
#
#
#
#
#   4%|▍         | 55/1261 [04:49<1:44:32,  5.20s/it]
#
#
#
#
#   4%|▍         | 56/1261 [04:54<1:44:32,  5.21s/it]
#
#
#
#
#   5%|▍         | 57/1261 [04:59<1:44:02,  5.19s/it]
#
#
#
#
#   5%|▍         | 58/1261 [05:04<1:43:40,  5.17s/it]
#
#
#
#
#   5%|▍         | 59/1261 [05:10<1:43:26,  5.16s/it]
#
#
#
#
#   5%|▍         | 60/1261 [05:15<1:43:03,  5.15s/it]
#
#
#
#
#   5%|▍         | 61/1261 [05:20<1:42:54,  5.15s/it]
#
#
#
#
#   5%|▍         | 62/1261 [05:25<1:42:51,  5.15s/it]
#
#
#
#
#   5%|▍         | 63/1261 [05:30<1:42:39,  5.14s/it]
#
#
#
#
#   5%|▌         | 64/1261 [05:35<1:42:32,  5.14s/it]
#
#
#
#
#   5%|▌         | 65/1261 [05:40<1:42:37,  5.15s/it]
#
#
#
#
#   5%|▌         | 66/1261 [05:46<1:45:06,  5.28s/it]
#
#
#
#
#   5%|▌         | 67/1261 [05:52<1:48:50,  5.47s/it]
#
#
#
#
#   5%|▌         | 68/1261 [05:57<1:49:33,  5.51s/it]
#
#
#
#
#   5%|▌         | 69/1261 [06:03<1:47:50,  5.43s/it]
#
#
#
#
#   6%|▌         | 70/1261 [06:08<1:46:35,  5.37s/it]
#
#
#
#
#   6%|▌         | 71/1261 [06:13<1:45:34,  5.32s/it]
#
#
#
#
#   6%|▌         | 72/1261 [06:19<1:45:47,  5.34s/it]
#
#
#
#
#   6%|▌         | 73/1261 [06:24<1:44:51,  5.30s/it]
#
#
#
#
#   6%|▌         | 74/1261 [06:29<1:43:49,  5.25s/it]
#
#
#
#
#   6%|▌         | 75/1261 [06:34<1:43:07,  5.22s/it]
#
#
#
#
#   6%|▌         | 76/1261 [06:39<1:43:31,  5.24s/it]
#
#
#
#
#   6%|▌         | 77/1261 [06:45<1:44:07,  5.28s/it]
#
#
#
#
#   6%|▌         | 78/1261 [06:50<1:43:20,  5.24s/it]
#
#
#
#
#   6%|▋         | 79/1261 [06:55<1:43:01,  5.23s/it]
#
#
#
#
#   6%|▋         | 80/1261 [07:00<1:42:25,  5.20s/it]
#
#
#
#
#   6%|▋         | 81/1261 [07:05<1:41:57,  5.18s/it]
#
#
#
#
#   7%|▋         | 82/1261 [07:10<1:41:40,  5.17s/it]
#
#
#
#
#   7%|▋         | 83/1261 [07:16<1:43:28,  5.27s/it]
#
#
#
#
#   7%|▋         | 84/1261 [07:21<1:44:27,  5.32s/it]
#
#
#
#
#   7%|▋         | 85/1261 [07:27<1:43:17,  5.27s/it]
#
#
#
#
#   7%|▋         | 86/1261 [07:32<1:42:26,  5.23s/it]
#
#
#
#
#   7%|▋         | 87/1261 [07:37<1:41:49,  5.20s/it]
#
#
#
#
#   7%|▋         | 88/1261 [07:42<1:41:26,  5.19s/it]
#
#
#
#
#   7%|▋         | 89/1261 [07:47<1:40:58,  5.17s/it]
#
#
#
#
#   7%|▋         | 90/1261 [07:52<1:41:42,  5.21s/it]
#
#
#
#
#   7%|▋         | 91/1261 [07:58<1:41:41,  5.21s/it]
#
#
#
#
#   7%|▋         | 92/1261 [08:03<1:41:33,  5.21s/it]
#
#
#
#
#   7%|▋         | 93/1261 [08:08<1:41:15,  5.20s/it]
#
#
#
#
#   7%|▋         | 94/1261 [08:13<1:41:15,  5.21s/it]
#
#
#
#
#   8%|▊         | 95/1261 [08:18<1:40:50,  5.19s/it]
#
#
#
#
#   8%|▊         | 96/1261 [08:24<1:40:28,  5.17s/it]
#
#
#
#
#   8%|▊         | 97/1261 [08:29<1:40:09,  5.16s/it]
#
#
#
#
#   8%|▊         | 98/1261 [08:34<1:39:55,  5.16s/it]
#
#
#
#
#   8%|▊         | 99/1261 [08:39<1:39:37,  5.14s/it]
#
#
#
#
#   8%|▊         | 100/1261 [08:44<1:39:39,  5.15s/it]
#
#
#
#
#   8%|▊         | 101/1261 [08:49<1:39:38,  5.15s/it]
#
#
#
#
#   8%|▊         | 102/1261 [08:54<1:39:31,  5.15s/it]
#
#
#
#
#   8%|▊         | 103/1261 [09:00<1:39:44,  5.17s/it]
#
#
#
#
#   8%|▊         | 104/1261 [09:05<1:39:38,  5.17s/it]
#
#
#
#
#   8%|▊         | 105/1261 [09:10<1:39:29,  5.16s/it]
#
#
#
#
#   8%|▊         | 106/1261 [09:15<1:39:14,  5.16s/it]
#
#
#
#
#   8%|▊         | 107/1261 [09:20<1:39:00,  5.15s/it]
#
#
#
#
#   9%|▊         | 108/1261 [09:25<1:39:02,  5.15s/it]
#
#
#
#
#   9%|▊         | 109/1261 [09:31<1:38:53,  5.15s/it]
#
#
#
#
#   9%|▊         | 110/1261 [09:36<1:39:28,  5.19s/it]
#
#
#
#
#   9%|▉         | 111/1261 [09:41<1:39:11,  5.18s/it]
#
#
#
#
#   9%|▉         | 112/1261 [09:46<1:38:59,  5.17s/it]
#
#
#
#
#   9%|▉         | 113/1261 [09:51<1:39:21,  5.19s/it]
#
#
#
#
#   9%|▉         | 114/1261 [09:57<1:39:26,  5.20s/it]
#
#
#
#
#   9%|▉         | 115/1261 [10:02<1:39:33,  5.21s/it]
#
#
#
#
#   9%|▉         | 116/1261 [10:07<1:39:23,  5.21s/it]
#
#
#
#
#   9%|▉         | 117/1261 [10:12<1:38:53,  5.19s/it]
#
#
#
#
#   9%|▉         | 118/1261 [10:17<1:38:31,  5.17s/it]
#
#
#
#
#   9%|▉         | 119/1261 [10:22<1:38:20,  5.17s/it]
#
#
#
#
#  10%|▉         | 120/1261 [10:28<1:38:10,  5.16s/it]
#
#
#
#
#  10%|▉         | 121/1261 [10:33<1:38:05,  5.16s/it]
#
#
#
#
#  10%|▉         | 122/1261 [10:38<1:37:46,  5.15s/it]
#
#
#
#
#  10%|▉         | 123/1261 [10:43<1:37:34,  5.14s/it]
#
#
#
#
#  10%|▉         | 124/1261 [10:48<1:37:26,  5.14s/it]
#
#
#
#
#  10%|▉         | 125/1261 [10:53<1:37:22,  5.14s/it]
#
#
#
#
#  10%|▉         | 126/1261 [10:58<1:37:16,  5.14s/it]
#
#
#
#
#  10%|█         | 127/1261 [11:04<1:37:58,  5.18s/it]
#
#
#
#
#  10%|█         | 128/1261 [11:09<1:38:07,  5.20s/it]
#
#
#
#
#  10%|█         | 129/1261 [11:14<1:37:31,  5.17s/it]
#
#
#
#
#  10%|█         | 130/1261 [11:19<1:38:02,  5.20s/it]
#
#
#
#
#  10%|█         | 131/1261 [11:25<1:39:37,  5.29s/it]
#
#
#
#
#  10%|█         | 132/1261 [11:30<1:40:52,  5.36s/it]
#
#
#
#
#  11%|█         | 133/1261 [11:36<1:41:29,  5.40s/it]
#
#
#
#
#  11%|█         | 134/1261 [11:41<1:39:49,  5.31s/it]
#
#
#
#
#  11%|█         | 135/1261 [11:46<1:38:45,  5.26s/it]
#
#
#
#
#  11%|█         | 136/1261 [11:51<1:38:26,  5.25s/it]
#
#
#
#
#  11%|█         | 137/1261 [11:56<1:37:41,  5.21s/it]
#
#
#
#
#  11%|█         | 138/1261 [12:02<1:37:07,  5.19s/it]
#
#
#
#
#  11%|█         | 139/1261 [12:07<1:37:14,  5.20s/it]
#
#
#
#
#  11%|█         | 140/1261 [12:12<1:37:19,  5.21s/it]
#
#
#
#
#  11%|█         | 141/1261 [12:17<1:36:53,  5.19s/it]
#
#
#
#
#  11%|█▏        | 142/1261 [12:22<1:36:41,  5.18s/it]
#
#
#
#
#  11%|█▏        | 143/1261 [12:27<1:36:19,  5.17s/it]
#
#
#
#
#  11%|█▏        | 144/1261 [12:33<1:36:10,  5.17s/it]
#
#
#
#
#  11%|█▏        | 145/1261 [12:38<1:36:03,  5.16s/it]
#
#
#
#
#  12%|█▏        | 146/1261 [12:43<1:35:52,  5.16s/it]
#
#
#
#
#  12%|█▏        | 147/1261 [12:48<1:36:02,  5.17s/it]
#
#
#
#
#  12%|█▏        | 148/1261 [12:53<1:35:46,  5.16s/it]
#
#
#
#
#  12%|█▏        | 149/1261 [12:58<1:35:40,  5.16s/it]
#
#
#
#
#  12%|█▏        | 150/1261 [13:04<1:35:26,  5.15s/it]
#
#
#
#
#  12%|█▏        | 151/1261 [13:09<1:35:37,  5.17s/it]
#
#
#
#
#  12%|█▏        | 152/1261 [13:14<1:36:13,  5.21s/it]
#
#
#
#
#  12%|█▏        | 153/1261 [13:19<1:35:53,  5.19s/it]
#
#
#
#
#  12%|█▏        | 154/1261 [13:24<1:35:29,  5.18s/it]
#
#
#
#
#  12%|█▏        | 155/1261 [13:29<1:34:59,  5.15s/it]
#
#
#
#
#  12%|█▏        | 156/1261 [13:35<1:34:49,  5.15s/it]
#
#
#
#
#  12%|█▏        | 157/1261 [13:40<1:34:44,  5.15s/it]
#
#
#
#
#  13%|█▎        | 158/1261 [13:45<1:34:37,  5.15s/it]
#
#
#
#
#  13%|█▎        | 159/1261 [13:50<1:34:50,  5.16s/it]
#
#
#
#
#  13%|█▎        | 160/1261 [13:55<1:34:44,  5.16s/it]
#
#
#
#
#  13%|█▎        | 161/1261 [14:01<1:35:57,  5.23s/it]
#
#
#
#
#  13%|█▎        | 162/1261 [14:06<1:38:05,  5.35s/it]
#
#
#
#
#  13%|█▎        | 163/1261 [14:12<1:39:11,  5.42s/it]
#
#
#
#
#  13%|█▎        | 164/1261 [14:18<1:40:56,  5.52s/it]
#
#
#
#
#  13%|█▎        | 165/1261 [14:23<1:39:56,  5.47s/it]
#
#
#
#
#  13%|█▎        | 166/1261 [14:28<1:38:24,  5.39s/it]
#
#
#
#
#  13%|█▎        | 167/1261 [14:34<1:39:17,  5.45s/it]
#
#
#
#
#  13%|█▎        | 168/1261 [14:39<1:39:40,  5.47s/it]
#
#
#
#
#  13%|█▎        | 169/1261 [14:45<1:38:47,  5.43s/it]
#
#
#
#
#  13%|█▎        | 170/1261 [14:50<1:37:30,  5.36s/it]
#
#
#
#
#  14%|█▎        | 171/1261 [14:55<1:37:26,  5.36s/it]
#
#
#
#
#  14%|█▎        | 172/1261 [15:00<1:36:04,  5.29s/it]
#
#
#
#
#  14%|█▎        | 173/1261 [15:06<1:37:38,  5.38s/it]
#
#
#
#
#  14%|█▍        | 174/1261 [15:11<1:38:04,  5.41s/it]
#
#
#
#
#  14%|█▍        | 175/1261 [15:17<1:37:27,  5.38s/it]
#
#
#
#
#  14%|█▍        | 176/1261 [15:22<1:36:46,  5.35s/it]
#
#
#
#
#  14%|█▍        | 177/1261 [15:27<1:37:01,  5.37s/it]
#
#
#
#
#  14%|█▍        | 178/1261 [15:33<1:37:51,  5.42s/it]
#
#
#
#
#  14%|█▍        | 179/1261 [15:38<1:37:38,  5.41s/it]
#
#
#
#
#  14%|█▍        | 180/1261 [15:44<1:37:32,  5.41s/it]
#
#
#
#
#  14%|█▍        | 181/1261 [15:49<1:37:05,  5.39s/it]
#
#
#
#
#  14%|█▍        | 182/1261 [15:54<1:36:04,  5.34s/it]
#
#
#
#
#  15%|█▍        | 183/1261 [15:59<1:34:54,  5.28s/it]
#
#
#
#
#  15%|█▍        | 184/1261 [16:05<1:34:59,  5.29s/it]
#
#
#
#
#  15%|█▍        | 185/1261 [16:10<1:35:45,  5.34s/it]
#
#
#
#
#  15%|█▍        | 186/1261 [16:16<1:37:27,  5.44s/it]
#
#
#
#
#  15%|█▍        | 187/1261 [16:22<1:39:55,  5.58s/it]
#
#
#
#
#  15%|█▍        | 188/1261 [16:27<1:38:25,  5.50s/it]
#
#
#
#
#  15%|█▍        | 189/1261 [16:33<1:37:54,  5.48s/it]
#
#
#
#
#  15%|█▌        | 190/1261 [16:38<1:37:08,  5.44s/it]
#
#
#
#
#  15%|█▌        | 191/1261 [16:43<1:36:44,  5.42s/it]
#
#
#
#
#  15%|█▌        | 192/1261 [16:49<1:38:07,  5.51s/it]
#
#
#
#
#  15%|█▌        | 193/1261 [16:54<1:36:56,  5.45s/it]
#
#
#
#
#  15%|█▌        | 194/1261 [17:00<1:36:12,  5.41s/it]
#
#
#
#
#  15%|█▌        | 195/1261 [17:05<1:35:24,  5.37s/it]
#
#
#
#
#  16%|█▌        | 196/1261 [17:10<1:35:00,  5.35s/it]
#
#
#
#
#  16%|█▌        | 197/1261 [17:16<1:34:33,  5.33s/it]
#
#
#
#
#  16%|█▌        | 198/1261 [17:21<1:34:28,  5.33s/it]
#
#
#
#
#  16%|█▌        | 199/1261 [17:26<1:34:40,  5.35s/it]
#
#
#
#
#  16%|█▌        | 200/1261 [17:32<1:34:14,  5.33s/it]
#
#
#
#
#  16%|█▌        | 201/1261 [17:37<1:33:58,  5.32s/it]
#
#
#
#
#  16%|█▌        | 202/1261 [17:43<1:35:52,  5.43s/it]
#
#
#
#
#  16%|█▌        | 203/1261 [17:48<1:35:35,  5.42s/it]
#
#
#
#
#  16%|█▌        | 204/1261 [17:53<1:35:30,  5.42s/it]
#
#
#
#
#  16%|█▋        | 205/1261 [17:59<1:34:58,  5.40s/it]
#
#
#
#
#  16%|█▋        | 206/1261 [18:04<1:35:50,  5.45s/it]
#
#
#
#
#  16%|█▋        | 207/1261 [18:10<1:35:56,  5.46s/it]
#
#
#
#
#  16%|█▋        | 208/1261 [18:15<1:35:15,  5.43s/it]
#
#
#
#
#  17%|█▋        | 209/1261 [18:20<1:34:43,  5.40s/it]
#
#
#
#
#  17%|█▋        | 210/1261 [18:26<1:34:50,  5.41s/it]
#
#
#
#
#  17%|█▋        | 211/1261 [18:31<1:34:22,  5.39s/it]
#
#
#
#
#  17%|█▋        | 212/1261 [18:37<1:34:15,  5.39s/it]
#
#
#
#
#  17%|█▋        | 213/1261 [18:42<1:34:27,  5.41s/it]
#
#
#
#
#  17%|█▋        | 214/1261 [18:47<1:33:58,  5.39s/it]
#
#
#
#
#  17%|█▋        | 215/1261 [18:53<1:33:41,  5.37s/it]
#
#
#
#
#  17%|█▋        | 216/1261 [18:58<1:33:49,  5.39s/it]
#
#
#
#
#  17%|█▋        | 217/1261 [19:03<1:33:30,  5.37s/it]
#
#
#
#
#  17%|█▋        | 218/1261 [19:09<1:33:16,  5.37s/it]
#
#
#
#
#  17%|█▋        | 219/1261 [19:14<1:33:07,  5.36s/it]
#
#
#
#
#  17%|█▋        | 220/1261 [19:20<1:32:52,  5.35s/it]
#
#
#
#
#  18%|█▊        | 221/1261 [19:25<1:32:44,  5.35s/it]
#
#
#
#
#  18%|█▊        | 222/1261 [19:30<1:32:54,  5.36s/it]
#
#
#
#
#  18%|█▊        | 223/1261 [19:36<1:32:35,  5.35s/it]
#
#
#
#
#  18%|█▊        | 224/1261 [19:41<1:32:28,  5.35s/it]
#
#
#
#
#  18%|█▊        | 225/1261 [19:46<1:32:06,  5.33s/it]
#
#
#
#
#  18%|█▊        | 226/1261 [19:52<1:34:04,  5.45s/it]
#
#
#
#
#  18%|█▊        | 227/1261 [19:57<1:33:13,  5.41s/it]
#  18%|█▊        | 228/1261 [20:03<1:33:40,  5.44s/it]
#
#
#
#
#  18%|█▊        | 229/1261 [20:09<1:35:26,  5.55s/it]
#
#
#
#
#  18%|█▊        | 230/1261 [20:14<1:34:45,  5.51s/it]
#
#
#
#
#  18%|█▊        | 231/1261 [20:19<1:33:43,  5.46s/it]
#
#
#
#
#  18%|█▊        | 232/1261 [20:25<1:32:45,  5.41s/it]
#
#
#
#
#  18%|█▊        | 233/1261 [20:30<1:32:08,  5.38s/it]
#
#
#
#
#  19%|█▊        | 234/1261 [20:35<1:32:09,  5.38s/it]
#
#
#
#
#  19%|█▊        | 235/1261 [20:41<1:31:36,  5.36s/it]
#
#
#
#
#  19%|█▊        | 236/1261 [20:46<1:31:14,  5.34s/it]
#
#
#
#
#  19%|█▉        | 237/1261 [20:51<1:30:51,  5.32s/it]
#
#
#
#
#  19%|█▉        | 238/1261 [20:57<1:30:42,  5.32s/it]
#
#
#
#
#  19%|█▉        | 239/1261 [21:02<1:30:26,  5.31s/it]
#
#
#
#
#  19%|█▉        | 240/1261 [21:07<1:30:19,  5.31s/it]
#
#
#
#
#  19%|█▉        | 241/1261 [21:12<1:30:04,  5.30s/it]
#
#
#
#
#  19%|█▉        | 242/1261 [21:18<1:31:14,  5.37s/it]
#
#
#
#
#  19%|█▉        | 243/1261 [21:23<1:30:54,  5.36s/it]
#
#
#
#
#  19%|█▉        | 244/1261 [21:29<1:30:23,  5.33s/it]
#
#
#
#
#  19%|█▉        | 245/1261 [21:34<1:30:19,  5.33s/it]
#
#
#
#
#  20%|█▉        | 246/1261 [21:39<1:29:54,  5.32s/it]
#
#
#
#
#  20%|█▉        | 247/1261 [21:44<1:29:35,  5.30s/it]
#
#
#
#
#  20%|█▉        | 248/1261 [21:50<1:29:34,  5.31s/it]
#
#
#
#
#  20%|█▉        | 249/1261 [21:55<1:29:31,  5.31s/it]
#
#
#
#
#  20%|█▉        | 250/1261 [22:00<1:29:34,  5.32s/it]
#
#
#
#
#  20%|█▉        | 251/1261 [22:06<1:29:28,  5.32s/it]
#
#
#
#
#  20%|█▉        | 252/1261 [22:11<1:29:10,  5.30s/it]
#
#
#
#
#  20%|██        | 253/1261 [22:16<1:28:55,  5.29s/it]
#
#
#
#
#  20%|██        | 254/1261 [22:22<1:28:44,  5.29s/it]
#
#
#
#
#  20%|██        | 255/1261 [22:27<1:28:43,  5.29s/it]
#
#
#
#
#  20%|██        | 256/1261 [22:32<1:28:47,  5.30s/it]
#
#
#
#
#  20%|██        | 257/1261 [22:37<1:28:52,  5.31s/it]
#
#
#
#
#  20%|██        | 258/1261 [22:43<1:28:41,  5.31s/it]
#
#
#
#
#  21%|██        | 259/1261 [22:48<1:28:33,  5.30s/it]
#
#
#
#
#  21%|██        | 260/1261 [22:53<1:28:39,  5.31s/it]
#
#
#
#
#  21%|██        | 261/1261 [22:59<1:28:22,  5.30s/it]
#
#
#
#
#  21%|██        | 262/1261 [23:04<1:28:04,  5.29s/it]
#
#
#
#
#  21%|██        | 263/1261 [23:09<1:28:11,  5.30s/it]
#
#
#
#
#  21%|██        | 264/1261 [23:15<1:28:00,  5.30s/it]
#
#
#
#
#  21%|██        | 265/1261 [23:20<1:27:49,  5.29s/it]
#
#
#
#
#  21%|██        | 266/1261 [23:25<1:27:37,  5.28s/it]
#
#
#
#
#  21%|██        | 267/1261 [23:30<1:27:33,  5.28s/it]
#
#
#
#
#  21%|██▏       | 268/1261 [23:36<1:28:24,  5.34s/it]
#
#
#
#
#  21%|██▏       | 269/1261 [23:41<1:28:39,  5.36s/it]
#
#
#
#
#  21%|██▏       | 270/1261 [23:47<1:28:14,  5.34s/it]
#
#
#
#
#  21%|██▏       | 271/1261 [23:52<1:28:13,  5.35s/it]
#
#
#
#
#  22%|██▏       | 272/1261 [23:57<1:27:57,  5.34s/it]
#
#
#
#
#  22%|██▏       | 273/1261 [24:03<1:27:39,  5.32s/it]
#
#
#
#
#  22%|██▏       | 274/1261 [24:08<1:27:22,  5.31s/it]
#
#
#
#
#  22%|██▏       | 275/1261 [24:13<1:27:10,  5.30s/it]
#
#
#
#
#  22%|██▏       | 276/1261 [24:18<1:26:50,  5.29s/it]
#
#
#
#
#  22%|██▏       | 277/1261 [24:24<1:26:44,  5.29s/it]
#
#
#
#
#  22%|██▏       | 278/1261 [24:29<1:26:39,  5.29s/it]
#
#
#
#
#  22%|██▏       | 279/1261 [24:34<1:26:39,  5.29s/it]
#
#
#
#
#  22%|██▏       | 280/1261 [24:40<1:26:36,  5.30s/it]
#
#
#
#
#  22%|██▏       | 281/1261 [24:45<1:26:41,  5.31s/it]
#
#
#
#
#  22%|██▏       | 282/1261 [24:50<1:26:42,  5.31s/it]
#
#
#
#
#  22%|██▏       | 283/1261 [24:56<1:26:44,  5.32s/it]
#
#
#
#
#  23%|██▎       | 284/1261 [25:01<1:26:35,  5.32s/it]
#
#
#
#
#  23%|██▎       | 285/1261 [25:06<1:26:24,  5.31s/it]
#
#
#
#
#  23%|██▎       | 286/1261 [25:11<1:26:14,  5.31s/it]
#
#
#
#
#  23%|██▎       | 287/1261 [25:17<1:26:01,  5.30s/it]
#
#
#
#
#  23%|██▎       | 288/1261 [25:22<1:26:03,  5.31s/it]
#
#
#
#
#  23%|██▎       | 289/1261 [25:27<1:25:55,  5.30s/it]
#
#
#
#
#  23%|██▎       | 290/1261 [25:33<1:26:00,  5.31s/it]
#
#
#
#
#  23%|██▎       | 291/1261 [25:38<1:25:48,  5.31s/it]
#
#
#
#
#  23%|██▎       | 292/1261 [25:43<1:25:42,  5.31s/it]
#
#
#
#
#  23%|██▎       | 293/1261 [25:49<1:25:56,  5.33s/it]
#
#
#
#
#  23%|██▎       | 294/1261 [25:54<1:26:15,  5.35s/it]
#
#
#
#
#  23%|██▎       | 295/1261 [25:59<1:26:00,  5.34s/it]
#
#
#
#
#  23%|██▎       | 296/1261 [26:05<1:25:46,  5.33s/it]
#
#
#
#
#  24%|██▎       | 297/1261 [26:10<1:25:27,  5.32s/it]
#
#
#
#
#  24%|██▎       | 298/1261 [26:15<1:25:18,  5.32s/it]
#
#
#
#
#  24%|██▎       | 299/1261 [26:21<1:25:05,  5.31s/it]
#
#
#
#
#  24%|██▍       | 300/1261 [26:26<1:24:55,  5.30s/it]
#
#
#
#
#  24%|██▍       | 301/1261 [26:31<1:24:50,  5.30s/it]
#
#
#
#
#  24%|██▍       | 302/1261 [26:36<1:24:49,  5.31s/it]
#
#
#
#
#  24%|██▍       | 303/1261 [26:42<1:24:30,  5.29s/it]
#
#
#
#
#  24%|██▍       | 304/1261 [26:47<1:24:15,  5.28s/it]
#
#
#
#
#  24%|██▍       | 305/1261 [26:52<1:24:30,  5.30s/it]
#
#
#
#
#  24%|██▍       | 306/1261 [26:58<1:24:21,  5.30s/it]
#
#
#
#
#  24%|██▍       | 307/1261 [27:03<1:24:06,  5.29s/it]
#
#
#
#
#  24%|██▍       | 308/1261 [27:08<1:24:17,  5.31s/it]
#
#
#
#
#  25%|██▍       | 309/1261 [27:14<1:23:57,  5.29s/it]
#
#
#
#
#  25%|██▍       | 310/1261 [27:19<1:23:46,  5.29s/it]
#
#
#
#
#  25%|██▍       | 311/1261 [27:24<1:23:54,  5.30s/it]
#
#
#
#
#  25%|██▍       | 312/1261 [27:29<1:23:57,  5.31s/it]
#
#
#
#
#  25%|██▍       | 313/1261 [27:35<1:23:50,  5.31s/it]
#
#
#
#
#  25%|██▍       | 314/1261 [27:40<1:23:44,  5.31s/it]
#
#
#
#
#  25%|██▍       | 315/1261 [27:45<1:23:36,  5.30s/it]
#
#
#
#
#  25%|██▌       | 316/1261 [27:51<1:23:41,  5.31s/it]
#
#
#
#
#  25%|██▌       | 317/1261 [27:56<1:23:40,  5.32s/it]
#
#
#
#
#  25%|██▌       | 318/1261 [28:01<1:23:25,  5.31s/it]
#
#
#
#
#  25%|██▌       | 319/1261 [28:07<1:23:19,  5.31s/it]
#
#
#
#
#  25%|██▌       | 320/1261 [28:12<1:23:22,  5.32s/it]
#
#
#
#
#  25%|██▌       | 321/1261 [28:17<1:23:22,  5.32s/it]
#
#
#
#
#  26%|██▌       | 322/1261 [28:23<1:23:07,  5.31s/it]
#
#
#
#
#  26%|██▌       | 323/1261 [28:28<1:22:50,  5.30s/it]
#
#
#
#
#  26%|██▌       | 324/1261 [28:33<1:22:30,  5.28s/it]
#
#
#
#
#  26%|██▌       | 325/1261 [28:38<1:22:21,  5.28s/it]
#
#
#
#
#  26%|██▌       | 326/1261 [28:44<1:22:27,  5.29s/it]
#
#
#
#
#  26%|██▌       | 327/1261 [28:49<1:22:27,  5.30s/it]
#
#
#
#
#  26%|██▌       | 328/1261 [28:54<1:22:19,  5.29s/it]
#
#
#
#
#  26%|██▌       | 329/1261 [29:00<1:22:31,  5.31s/it]
#
#
#
#
#  26%|██▌       | 330/1261 [29:05<1:22:15,  5.30s/it]
#
#
#
#
#  26%|██▌       | 331/1261 [29:10<1:22:25,  5.32s/it]
#
#
#
#
#  26%|██▋       | 332/1261 [29:16<1:22:19,  5.32s/it]
#
#
#
#
#  26%|██▋       | 333/1261 [29:21<1:22:13,  5.32s/it]
#
#
#
#
#  26%|██▋       | 334/1261 [29:26<1:22:09,  5.32s/it]
#
#
#
#
#  27%|██▋       | 335/1261 [29:32<1:21:55,  5.31s/it]
#
#
#
#
#  27%|██▋       | 336/1261 [29:37<1:21:35,  5.29s/it]
#
#
#
#
#  27%|██▋       | 337/1261 [29:42<1:21:24,  5.29s/it]
#
#
#
#
#  27%|██▋       | 338/1261 [29:47<1:21:26,  5.29s/it]
#
#
#
#
#  27%|██▋       | 339/1261 [29:53<1:21:35,  5.31s/it]
#
#
#
#
#  27%|██▋       | 340/1261 [29:58<1:21:34,  5.31s/it]
#
#
#
#
#  27%|██▋       | 341/1261 [30:03<1:21:43,  5.33s/it]
#
#
#
#
#  27%|██▋       | 342/1261 [30:09<1:21:28,  5.32s/it]
#
#
#
#
#  27%|██▋       | 343/1261 [30:14<1:21:16,  5.31s/it]
#
#
#
#
#  27%|██▋       | 344/1261 [30:19<1:21:05,  5.31s/it]
#
#
#
#
#  27%|██▋       | 345/1261 [30:25<1:21:06,  5.31s/it]
#
#
#
#
#  27%|██▋       | 346/1261 [30:30<1:21:11,  5.32s/it]
#
#
#
#
#  28%|██▊       | 347/1261 [30:35<1:20:53,  5.31s/it]
#
#
#
#
#  28%|██▊       | 348/1261 [30:41<1:20:48,  5.31s/it]
#
#
#
#
#  28%|██▊       | 349/1261 [30:46<1:20:47,  5.31s/it]
#
#
#
#
#  28%|██▊       | 350/1261 [30:51<1:20:53,  5.33s/it]
#
#
#
#
#  28%|██▊       | 351/1261 [30:56<1:20:34,  5.31s/it]
#
#
#
#
#  28%|██▊       | 352/1261 [31:02<1:20:48,  5.33s/it]
#
#
#
#
#  28%|██▊       | 353/1261 [31:07<1:21:21,  5.38s/it]
#
#
#
#
#  28%|██▊       | 354/1261 [31:13<1:21:26,  5.39s/it]
#
#
#
#
#  28%|██▊       | 355/1261 [31:18<1:21:19,  5.39s/it]
#
#
#
#
#  28%|██▊       | 356/1261 [31:24<1:21:08,  5.38s/it]
#
#
#
#
#  28%|██▊       | 357/1261 [31:29<1:21:03,  5.38s/it]
#
#
#
#
#  28%|██▊       | 358/1261 [31:34<1:20:50,  5.37s/it]
#
#
#
#
#  28%|██▊       | 359/1261 [31:40<1:20:37,  5.36s/it]
#
#
#
#
#  29%|██▊       | 360/1261 [31:45<1:20:26,  5.36s/it]
#
#
#
#
#  29%|██▊       | 361/1261 [31:50<1:20:26,  5.36s/it]
#
#
#
#
#  29%|██▊       | 362/1261 [31:56<1:20:06,  5.35s/it]
#
#
#
#
#  29%|██▉       | 363/1261 [32:01<1:19:34,  5.32s/it]
#
#
#
#
#  29%|██▉       | 364/1261 [32:06<1:19:21,  5.31s/it]
#
#
#
#
#  29%|██▉       | 365/1261 [32:11<1:18:58,  5.29s/it]
#
#
#
#
#  29%|██▉       | 366/1261 [32:16<1:18:05,  5.24s/it]
#
#
#
#
#  29%|██▉       | 367/1261 [32:22<1:17:47,  5.22s/it]
#
#
#
#
#  29%|██▉       | 368/1261 [32:27<1:17:28,  5.21s/it]
#
#
#
#
#  29%|██▉       | 369/1261 [32:32<1:17:35,  5.22s/it]
#
#
#
#
#  29%|██▉       | 370/1261 [32:37<1:17:14,  5.20s/it]
#
#
#
#
#  29%|██▉       | 371/1261 [32:42<1:17:04,  5.20s/it]
#
#
#
#
#  30%|██▉       | 372/1261 [32:48<1:17:05,  5.20s/it]
#
#
#
#
#  30%|██▉       | 373/1261 [32:53<1:16:46,  5.19s/it]
#
#
#
#
#  30%|██▉       | 374/1261 [32:58<1:16:38,  5.18s/it]
#
#
#
#
#  30%|██▉       | 375/1261 [33:03<1:16:17,  5.17s/it]
#
#
#
#
#  30%|██▉       | 376/1261 [33:08<1:16:14,  5.17s/it]
#
#
#
#
#  30%|██▉       | 377/1261 [33:14<1:16:24,  5.19s/it]
#
#
#
#
#  30%|██▉       | 378/1261 [33:19<1:16:21,  5.19s/it]
#
#
#
#
#  30%|███       | 379/1261 [33:24<1:16:26,  5.20s/it]
#
#
#
#
#  30%|███       | 380/1261 [33:29<1:16:28,  5.21s/it]
#
#
#
#
#  30%|███       | 381/1261 [33:34<1:16:10,  5.19s/it]
#
#
#
#
#  30%|███       | 382/1261 [33:40<1:15:59,  5.19s/it]
#
#
#
#
#  30%|███       | 383/1261 [33:45<1:15:42,  5.17s/it]
#
#
#
#
#  30%|███       | 384/1261 [33:50<1:15:25,  5.16s/it]
#
#
#
#
#  31%|███       | 385/1261 [33:55<1:16:06,  5.21s/it]
#
#
#
#
#  31%|███       | 386/1261 [34:01<1:17:15,  5.30s/it]
#
#
#
#
#  31%|███       | 387/1261 [34:06<1:17:43,  5.34s/it]
#
#
#
#
#  31%|███       | 388/1261 [34:11<1:17:49,  5.35s/it]
#
#
#
#
#  31%|███       | 389/1261 [34:17<1:17:28,  5.33s/it]
#
#
#
#
#  31%|███       | 390/1261 [34:22<1:17:09,  5.32s/it]
#
#
#
#
#  31%|███       | 391/1261 [34:27<1:17:24,  5.34s/it]
#
#
#
#
#  31%|███       | 392/1261 [34:33<1:17:25,  5.35s/it]
#
#
#
#
#  31%|███       | 393/1261 [34:38<1:17:31,  5.36s/it]
#
#
#
#
#  31%|███       | 394/1261 [34:44<1:17:50,  5.39s/it]
#
#
#
#
#  31%|███▏      | 395/1261 [34:49<1:18:14,  5.42s/it]
#
#
#
#
#  31%|███▏      | 396/1261 [34:55<1:18:10,  5.42s/it]
#
#
#
#
#  31%|███▏      | 397/1261 [35:00<1:18:02,  5.42s/it]
#
#
#
#
#  32%|███▏      | 398/1261 [35:05<1:18:09,  5.43s/it]
#
#
#
#
#  32%|███▏      | 399/1261 [35:11<1:19:19,  5.52s/it]
#
#
#
#
#  32%|███▏      | 400/1261 [35:17<1:20:10,  5.59s/it]
#
#
#
#
#  32%|███▏      | 401/1261 [35:22<1:19:42,  5.56s/it]
#
#
#
#
#  32%|███▏      | 402/1261 [35:28<1:20:13,  5.60s/it]
#
#
#
#
#  32%|███▏      | 403/1261 [35:33<1:19:04,  5.53s/it]
#
#
#
#
#  32%|███▏      | 404/1261 [35:39<1:18:37,  5.50s/it]
#
#
#
#
#  32%|███▏      | 405/1261 [35:44<1:18:00,  5.47s/it]
#
#
#
#
#  32%|███▏      | 406/1261 [35:50<1:17:14,  5.42s/it]
#
#
#
#
#  32%|███▏      | 407/1261 [35:55<1:16:41,  5.39s/it]
#
#
#
#
#  32%|███▏      | 408/1261 [36:00<1:16:12,  5.36s/it]
#
#
#
#
#  32%|███▏      | 409/1261 [36:06<1:16:19,  5.37s/it]
#
#
#
#
#  33%|███▎      | 410/1261 [36:11<1:15:59,  5.36s/it]
#
#
#
#
#  33%|███▎      | 411/1261 [36:16<1:15:47,  5.35s/it]
#
#
#
#
#  33%|███▎      | 412/1261 [36:22<1:16:12,  5.39s/it]
#
#
#
#
#  33%|███▎      | 413/1261 [36:27<1:15:44,  5.36s/it]
#
#
#
#
#  33%|███▎      | 414/1261 [36:32<1:15:23,  5.34s/it]
#
#
#
#
#  33%|███▎      | 415/1261 [36:38<1:15:09,  5.33s/it]
#
#
#
#
#  33%|███▎      | 416/1261 [36:43<1:14:49,  5.31s/it]
#
#
#
#
#  33%|███▎      | 417/1261 [36:48<1:15:27,  5.36s/it]
#
#
#
#
#  33%|███▎      | 418/1261 [36:54<1:15:23,  5.37s/it]
#
#
#
#
#  33%|███▎      | 419/1261 [36:59<1:15:25,  5.37s/it]
#
#
#
#
#  33%|███▎      | 420/1261 [37:05<1:16:01,  5.42s/it]
#
#
#
#
#  33%|███▎      | 421/1261 [37:10<1:15:44,  5.41s/it]
#
#
#
#
#  33%|███▎      | 422/1261 [37:15<1:15:09,  5.38s/it]
#
#
#
#
#  34%|███▎      | 423/1261 [37:21<1:14:58,  5.37s/it]
#
#
#
#
#  34%|███▎      | 424/1261 [37:26<1:14:37,  5.35s/it]
#
#
#
#
#  34%|███▎      | 425/1261 [37:31<1:14:22,  5.34s/it]
#
#
#
#
#  34%|███▍      | 426/1261 [37:37<1:14:07,  5.33s/it]
#
#
#
#
#  34%|███▍      | 427/1261 [37:42<1:13:54,  5.32s/it]
#
#
#
#
#  34%|███▍      | 428/1261 [37:47<1:13:41,  5.31s/it]
#
#
#
#
#  34%|███▍      | 429/1261 [37:53<1:13:48,  5.32s/it]
#
#
#
#
#  34%|███▍      | 430/1261 [37:58<1:13:36,  5.32s/it]
#
#
#
#
#  34%|███▍      | 431/1261 [38:03<1:13:54,  5.34s/it]
#
#
#
#
#  34%|███▍      | 432/1261 [38:09<1:16:19,  5.52s/it]
#
#
#
#
#  34%|███▍      | 433/1261 [38:15<1:17:01,  5.58s/it]
#
#
#
#
#  34%|███▍      | 434/1261 [38:20<1:17:01,  5.59s/it]
#
#
#
#
#  34%|███▍      | 435/1261 [38:27<1:18:45,  5.72s/it]
#
#
#
#
#  35%|███▍      | 436/1261 [38:32<1:17:24,  5.63s/it]
#
#
#
#
#  35%|███▍      | 437/1261 [38:37<1:16:56,  5.60s/it]
#
#
#
#
#  35%|███▍      | 438/1261 [38:43<1:15:35,  5.51s/it]
#
#
#
#
#  35%|███▍      | 439/1261 [38:48<1:14:38,  5.45s/it]
#
#
#
#
#  35%|███▍      | 440/1261 [38:53<1:13:54,  5.40s/it]
#
#
#
#
#  35%|███▍      | 441/1261 [38:59<1:14:20,  5.44s/it]
#
#
#
#
#  35%|███▌      | 442/1261 [39:05<1:15:58,  5.57s/it]
#
#
#
#
#  35%|███▌      | 443/1261 [39:10<1:14:59,  5.50s/it]
#
#
#
#
#  35%|███▌      | 444/1261 [39:15<1:14:02,  5.44s/it]
#
#
#
#
#  35%|███▌      | 445/1261 [39:21<1:13:21,  5.39s/it]
#
#
#
#
#  35%|███▌      | 446/1261 [39:26<1:13:13,  5.39s/it]
#
#
#
#
#  35%|███▌      | 447/1261 [39:31<1:12:46,  5.36s/it]
#
#
#
#
#  36%|███▌      | 448/1261 [39:37<1:12:31,  5.35s/it]
#
#
#
#
#  36%|███▌      | 449/1261 [39:42<1:12:20,  5.34s/it]
#
#
#
#
#  36%|███▌      | 450/1261 [39:47<1:12:01,  5.33s/it]
#
#
#
#
#  36%|███▌      | 451/1261 [39:53<1:11:57,  5.33s/it]
#
#
#
#
#  36%|███▌      | 452/1261 [39:58<1:11:51,  5.33s/it]
#
#
#
#
#  36%|███▌      | 453/1261 [40:03<1:11:52,  5.34s/it]
#  36%|███▌      | 454/1261 [40:09<1:12:19,  5.38s/it]
#
#
#
#
#  36%|███▌      | 455/1261 [40:14<1:12:59,  5.43s/it]
#
#
#
#
#  36%|███▌      | 456/1261 [40:20<1:12:28,  5.40s/it]
#
#
#
#
#  36%|███▌      | 457/1261 [40:25<1:12:31,  5.41s/it]
#
#
#
#
#  36%|███▋      | 458/1261 [40:31<1:12:16,  5.40s/it]
#
#
#
#
#  36%|███▋      | 459/1261 [40:36<1:11:45,  5.37s/it]
#
#
#
#
#  36%|███▋      | 460/1261 [40:41<1:11:36,  5.36s/it]
#
#
#
#
#  37%|███▋      | 461/1261 [40:46<1:11:09,  5.34s/it]
#
#
#
#
#  37%|███▋      | 462/1261 [40:52<1:10:46,  5.31s/it]
#
#
#
#
#  37%|███▋      | 463/1261 [40:57<1:10:40,  5.31s/it]
#
#
#
#
#  37%|███▋      | 464/1261 [41:02<1:10:35,  5.31s/it]
#
#
#
#
#  37%|███▋      | 465/1261 [41:08<1:10:23,  5.31s/it]
#
#
#
#
#  37%|███▋      | 466/1261 [41:13<1:10:26,  5.32s/it]
#
#
#
#
#  37%|███▋      | 467/1261 [41:19<1:11:36,  5.41s/it]
#
#
#
#
#  37%|███▋      | 468/1261 [41:24<1:12:52,  5.51s/it]
#
#
#
#
#  37%|███▋      | 469/1261 [41:30<1:13:11,  5.55s/it]
#
#
#
#
#  37%|███▋      | 470/1261 [41:35<1:12:30,  5.50s/it]
#
#
#
#
#  37%|███▋      | 471/1261 [41:41<1:11:37,  5.44s/it]
#
#
#
#
#  37%|███▋      | 472/1261 [41:46<1:10:56,  5.40s/it]
#
#
#
#
#  38%|███▊      | 473/1261 [41:51<1:10:52,  5.40s/it]
#
#
#
#
#  38%|███▊      | 474/1261 [41:57<1:10:21,  5.36s/it]
#
#
#
#
#  38%|███▊      | 475/1261 [42:02<1:09:53,  5.34s/it]
#
#
#
#
#  38%|███▊      | 476/1261 [42:07<1:09:43,  5.33s/it]
#
#
#
#
#  38%|███▊      | 477/1261 [42:12<1:09:27,  5.32s/it]
#
#
#
#
#  38%|███▊      | 478/1261 [42:18<1:09:26,  5.32s/it]
#
#
#
#
#  38%|███▊      | 479/1261 [42:23<1:09:12,  5.31s/it]
#
#
#
#
#  38%|███▊      | 480/1261 [42:28<1:08:57,  5.30s/it]
#
#
#
#
#  38%|███▊      | 481/1261 [42:34<1:09:03,  5.31s/it]
#
#
#
#
#  38%|███▊      | 482/1261 [42:39<1:08:52,  5.30s/it]
#
#
#
#
#  38%|███▊      | 483/1261 [42:44<1:08:46,  5.30s/it]
#
#
#
#
#  38%|███▊      | 484/1261 [42:50<1:08:34,  5.30s/it]
#
#
#
#
#  38%|███▊      | 485/1261 [42:55<1:08:30,  5.30s/it]
#
#
#
#
#  39%|███▊      | 486/1261 [43:00<1:08:31,  5.31s/it]
#
#
#
#
#  39%|███▊      | 487/1261 [43:06<1:08:32,  5.31s/it]
#
#
#
#
#  39%|███▊      | 488/1261 [43:11<1:08:31,  5.32s/it]
#
#
#
#
#  39%|███▉      | 489/1261 [43:16<1:08:14,  5.30s/it]
#
#
#
#
#  39%|███▉      | 490/1261 [43:21<1:08:08,  5.30s/it]
#
#
#
#
#  39%|███▉      | 491/1261 [43:27<1:08:11,  5.31s/it]
#
#
#
#
#  39%|███▉      | 492/1261 [43:32<1:08:11,  5.32s/it]
#
#
#
#
#  39%|███▉      | 493/1261 [43:38<1:08:22,  5.34s/it]
#
#
#
#
#  39%|███▉      | 494/1261 [43:43<1:08:12,  5.34s/it]
#
#
#
#
#  39%|███▉      | 495/1261 [43:48<1:07:50,  5.31s/it]
#
#
#
#
#  39%|███▉      | 496/1261 [43:54<1:08:05,  5.34s/it]
#
#
#
#
#  39%|███▉      | 497/1261 [43:59<1:07:48,  5.33s/it]
#
#
#
#
#  39%|███▉      | 498/1261 [44:04<1:07:38,  5.32s/it]
#
#
#
#
#  40%|███▉      | 499/1261 [44:09<1:07:23,  5.31s/it]
#
#
#
#
#  40%|███▉      | 500/1261 [44:15<1:07:12,  5.30s/it]
#
#
#
#
#  40%|███▉      | 501/1261 [44:20<1:06:59,  5.29s/it]
#
#
#
#
#  40%|███▉      | 502/1261 [44:25<1:07:00,  5.30s/it]
#
#
#
#
#  40%|███▉      | 503/1261 [44:31<1:07:10,  5.32s/it]
#
#
#
#
#  40%|███▉      | 504/1261 [44:36<1:07:01,  5.31s/it]
#
#
#
#
#  40%|████      | 505/1261 [44:41<1:07:04,  5.32s/it]
#
#
#
#
#  40%|████      | 506/1261 [44:47<1:06:57,  5.32s/it]
#
#
#
#
#  40%|████      | 507/1261 [44:52<1:06:44,  5.31s/it]
#
#
#
#
#  40%|████      | 508/1261 [44:57<1:07:43,  5.40s/it]
#
#
#
#
#  40%|████      | 509/1261 [45:03<1:08:46,  5.49s/it]
#
#
#
#
#  40%|████      | 510/1261 [45:09<1:08:35,  5.48s/it]
#
#
#
#
#  41%|████      | 511/1261 [45:14<1:07:49,  5.43s/it]
#
#
#
#
#  41%|████      | 512/1261 [45:19<1:07:18,  5.39s/it]
#
#
#
#
#  41%|████      | 513/1261 [45:25<1:06:52,  5.36s/it]
#
#
#
#
#  41%|████      | 514/1261 [45:30<1:06:27,  5.34s/it]
#
#
#
#
#  41%|████      | 515/1261 [45:35<1:06:09,  5.32s/it]
#
#
#
#
#  41%|████      | 516/1261 [45:40<1:05:58,  5.31s/it]
#
#
#
#
#  41%|████      | 517/1261 [45:46<1:05:58,  5.32s/it]
#
#
#
#
#  41%|████      | 518/1261 [45:51<1:05:52,  5.32s/it]
#
#
#
#
#  41%|████      | 519/1261 [45:56<1:05:46,  5.32s/it]
#
#
#
#
#  41%|████      | 520/1261 [46:02<1:05:57,  5.34s/it]
#
#
#
#
#  41%|████▏     | 521/1261 [46:07<1:05:46,  5.33s/it]
#
#
#
#
#  41%|████▏     | 522/1261 [46:12<1:05:34,  5.32s/it]
#
#
#
#
#  41%|████▏     | 523/1261 [46:18<1:05:33,  5.33s/it]
#
#
#
#
#  42%|████▏     | 524/1261 [46:23<1:05:23,  5.32s/it]
#
#
#
#
#  42%|████▏     | 525/1261 [46:28<1:05:08,  5.31s/it]
#
#
#
#
#  42%|████▏     | 526/1261 [46:34<1:04:56,  5.30s/it]
#
#
#
#
#  42%|████▏     | 527/1261 [46:39<1:04:55,  5.31s/it]
#
#
#
#
#  42%|████▏     | 528/1261 [46:44<1:04:50,  5.31s/it]
#
#
#
#
#  42%|████▏     | 529/1261 [46:50<1:04:55,  5.32s/it]
#
#
#
#
#  42%|████▏     | 530/1261 [46:55<1:04:39,  5.31s/it]
#
#
#
#
#  42%|████▏     | 531/1261 [47:00<1:04:31,  5.30s/it]
#
#
#
#
#  42%|████▏     | 532/1261 [47:05<1:04:17,  5.29s/it]
#
#
#
#
#  42%|████▏     | 533/1261 [47:11<1:04:10,  5.29s/it]
#
#
#
#
#  42%|████▏     | 534/1261 [47:16<1:04:01,  5.28s/it]
#
#
#
#
#  42%|████▏     | 535/1261 [47:21<1:03:55,  5.28s/it]
#
#
#
#
#  43%|████▎     | 536/1261 [47:27<1:03:51,  5.28s/it]
#
#
#
#
#  43%|████▎     | 537/1261 [47:32<1:03:47,  5.29s/it]
#
#
#
#
#  43%|████▎     | 538/1261 [47:37<1:03:49,  5.30s/it]
#
#
#
#
#  43%|████▎     | 539/1261 [47:43<1:04:02,  5.32s/it]
#
#
#
#
#  43%|████▎     | 540/1261 [47:48<1:03:49,  5.31s/it]
#
#
#
#
#  43%|████▎     | 541/1261 [47:53<1:04:38,  5.39s/it]
#
#
#
#
#  43%|████▎     | 542/1261 [47:59<1:04:15,  5.36s/it]
#
#
#
#
#  43%|████▎     | 543/1261 [48:04<1:04:04,  5.36s/it]
#
#
#
#
#  43%|████▎     | 544/1261 [48:09<1:03:58,  5.35s/it]
#
#
#
#
#  43%|████▎     | 545/1261 [48:15<1:03:48,  5.35s/it]
#
#
#
#
#  43%|████▎     | 546/1261 [48:20<1:03:26,  5.32s/it]
#
#
#
#
#  43%|████▎     | 547/1261 [48:25<1:03:17,  5.32s/it]
#
#
#
#
#  43%|████▎     | 548/1261 [48:31<1:03:07,  5.31s/it]
#
#
#
#
#  44%|████▎     | 549/1261 [48:36<1:03:12,  5.33s/it]
#
#
#
#
#  44%|████▎     | 550/1261 [48:41<1:03:10,  5.33s/it]
#
#
#
#
#  44%|████▎     | 551/1261 [48:47<1:03:02,  5.33s/it]
#
#
#
#
#  44%|████▍     | 552/1261 [48:52<1:03:03,  5.34s/it]
#
#
#
#
#  44%|████▍     | 553/1261 [48:57<1:02:57,  5.34s/it]
#
#
#
#
#  44%|████▍     | 554/1261 [49:03<1:02:45,  5.33s/it]
#
#
#
#
#  44%|████▍     | 555/1261 [49:08<1:02:31,  5.31s/it]
#
#
#
#
#  44%|████▍     | 556/1261 [49:13<1:02:25,  5.31s/it]
#
#
#
#
#  44%|████▍     | 557/1261 [49:18<1:02:17,  5.31s/it]
#
#
#
#
#  44%|████▍     | 558/1261 [49:24<1:02:11,  5.31s/it]
#
#
#
#
#  44%|████▍     | 559/1261 [49:29<1:02:09,  5.31s/it]
#
#
#
#
#  44%|████▍     | 560/1261 [49:34<1:02:06,  5.32s/it]
#
#
#
#
#  44%|████▍     | 561/1261 [49:40<1:02:01,  5.32s/it]
#
#
#
#
#  45%|████▍     | 562/1261 [49:45<1:01:51,  5.31s/it]
#
#
#
#
#  45%|████▍     | 563/1261 [49:50<1:01:58,  5.33s/it]
#
#
#
#
#  45%|████▍     | 564/1261 [49:56<1:02:04,  5.34s/it]
#
#
#
#
#  45%|████▍     | 565/1261 [50:01<1:01:52,  5.33s/it]
#
#
#
#
#  45%|████▍     | 566/1261 [50:06<1:01:40,  5.32s/it]
#
#
#
#
#  45%|████▍     | 567/1261 [50:12<1:01:28,  5.31s/it]
#
#
#
#
#  45%|████▌     | 568/1261 [50:17<1:01:13,  5.30s/it]
#
#
#
#
#  45%|████▌     | 569/1261 [50:22<1:01:00,  5.29s/it]
#
#
#
#
#  45%|████▌     | 570/1261 [50:28<1:01:01,  5.30s/it]
#
#
#
#
#  45%|████▌     | 571/1261 [50:33<1:00:48,  5.29s/it]
#
#
#
#
#  45%|████▌     | 572/1261 [50:38<1:00:46,  5.29s/it]
#
#
#
#
#  45%|████▌     | 573/1261 [50:43<1:00:45,  5.30s/it]
#
#
#
#
#  46%|████▌     | 574/1261 [50:49<1:00:34,  5.29s/it]
#
#
#
#
#  46%|████▌     | 575/1261 [50:54<1:00:24,  5.28s/it]
#
#
#
#
#  46%|████▌     | 576/1261 [50:59<1:00:32,  5.30s/it]
#
#
#
#
#  46%|████▌     | 577/1261 [51:05<1:00:39,  5.32s/it]
#
#
#
#
#  46%|████▌     | 578/1261 [51:10<1:00:32,  5.32s/it]
#
#
#
#
#  46%|████▌     | 579/1261 [51:15<1:00:14,  5.30s/it]
#
#
#
#
#  46%|████▌     | 580/1261 [51:21<1:00:08,  5.30s/it]
#
#
#
#
#  46%|████▌     | 581/1261 [51:26<59:58,  5.29s/it]
#
#
#
#
#  46%|████▌     | 582/1261 [51:31<59:46,  5.28s/it]
#
#
#
#
#  46%|████▌     | 583/1261 [51:36<59:41,  5.28s/it]
#
#
#
#
#  46%|████▋     | 584/1261 [51:42<59:33,  5.28s/it]
#
#
#
#
#  46%|████▋     | 585/1261 [51:47<59:24,  5.27s/it]
#
#
#
#
#  46%|████▋     | 586/1261 [51:52<59:33,  5.29s/it]
#
#
#
#
#  47%|████▋     | 587/1261 [51:58<59:25,  5.29s/it]
#
#
#
#
#  47%|████▋     | 588/1261 [52:03<59:32,  5.31s/it]
#
#
#
#
#  47%|████▋     | 589/1261 [52:08<59:26,  5.31s/it]
#
#
#
#
#  47%|████▋     | 590/1261 [52:13<59:08,  5.29s/it]
#
#
#
#
#  47%|████▋     | 591/1261 [52:19<58:59,  5.28s/it]
#
#
#
#
#  47%|████▋     | 592/1261 [52:24<58:57,  5.29s/it]
#
#
#
#
#  47%|████▋     | 593/1261 [52:29<58:51,  5.29s/it]
#
#
#
#
#  47%|████▋     | 594/1261 [52:35<58:46,  5.29s/it]
#
#
#
#
#  47%|████▋     | 595/1261 [52:40<58:39,  5.28s/it]
#
#
#
#
#  47%|████▋     | 596/1261 [52:45<58:35,  5.29s/it]
#
#
#
#
#  47%|████▋     | 597/1261 [52:50<58:34,  5.29s/it]
#
#
#
#
#  47%|████▋     | 598/1261 [52:56<58:30,  5.29s/it]
#
#
#
#
#  48%|████▊     | 599/1261 [53:01<58:19,  5.29s/it]
#
#
#
#
#  48%|████▊     | 600/1261 [53:06<58:30,  5.31s/it]
#
#
#
#
#  48%|████▊     | 601/1261 [53:12<58:28,  5.32s/it]
#
#
#
#
#  48%|████▊     | 602/1261 [53:17<58:18,  5.31s/it]
#
#
#
#
#  48%|████▊     | 603/1261 [53:22<58:06,  5.30s/it]
#
#
#
#
#  48%|████▊     | 604/1261 [53:28<57:59,  5.30s/it]
#
#
#
#
#  48%|████▊     | 605/1261 [53:33<57:51,  5.29s/it]
#
#
#
#
#  48%|████▊     | 606/1261 [53:38<57:48,  5.30s/it]
#
#
#
#
#  48%|████▊     | 607/1261 [53:43<57:40,  5.29s/it]
#
#
#
#
#  48%|████▊     | 608/1261 [53:49<57:33,  5.29s/it]
#
#
#
#
#  48%|████▊     | 609/1261 [53:54<57:58,  5.33s/it]
#
#
#
#
#  48%|████▊     | 610/1261 [54:00<58:00,  5.35s/it]
#
#
#
#
#  48%|████▊     | 611/1261 [54:05<57:41,  5.33s/it]
#
#
#
#
#  49%|████▊     | 612/1261 [54:10<57:39,  5.33s/it]
#
#
#
#
#  49%|████▊     | 613/1261 [54:15<57:29,  5.32s/it]
#
#
#
#
#  49%|████▊     | 614/1261 [54:21<57:10,  5.30s/it]
#
#
#
#
#  49%|████▉     | 615/1261 [54:26<57:03,  5.30s/it]
#
#
#
#
#  49%|████▉     | 616/1261 [54:31<56:52,  5.29s/it]
#
#
#
#
#  49%|████▉     | 617/1261 [54:37<56:47,  5.29s/it]
#
#
#
#
#  49%|████▉     | 618/1261 [54:42<56:42,  5.29s/it]
#
#
#
#
#  49%|████▉     | 619/1261 [54:47<56:39,  5.29s/it]
#
#
#
#
#  49%|████▉     | 620/1261 [54:52<56:45,  5.31s/it]
#
#
#
#
#  49%|████▉     | 621/1261 [54:58<56:38,  5.31s/it]
#
#
#
#
#  49%|████▉     | 622/1261 [55:03<56:30,  5.31s/it]
#
#
#
#
#  49%|████▉     | 623/1261 [55:08<56:18,  5.29s/it]
#
#
#
#
#  49%|████▉     | 624/1261 [55:14<56:39,  5.34s/it]
#
#
#
#
#  50%|████▉     | 625/1261 [55:19<56:28,  5.33s/it]
#
#
#
#
#  50%|████▉     | 626/1261 [55:24<56:24,  5.33s/it]
#
#
#
#
#  50%|████▉     | 627/1261 [55:30<56:10,  5.32s/it]
#
#
#
#
#  50%|████▉     | 628/1261 [55:35<55:58,  5.31s/it]
#
#
#
#
#  50%|████▉     | 629/1261 [55:40<55:51,  5.30s/it]
#
#
#
#
#  50%|████▉     | 630/1261 [55:46<55:39,  5.29s/it]
#
#
#
#
#  50%|█████     | 631/1261 [55:51<55:37,  5.30s/it]
#
#
#
#
#  50%|█████     | 632/1261 [55:56<55:32,  5.30s/it]
#
#
#
#
#  50%|█████     | 633/1261 [56:01<55:26,  5.30s/it]
#
#
#
#
#  50%|█████     | 634/1261 [56:07<55:24,  5.30s/it]
#
#
#
#
#  50%|█████     | 635/1261 [56:12<55:36,  5.33s/it]
#
#
#
#
#  50%|█████     | 636/1261 [56:18<55:46,  5.36s/it]
#
#
#
#
#  51%|█████     | 637/1261 [56:23<55:36,  5.35s/it]
#
#
#
#
#  51%|█████     | 638/1261 [56:28<55:20,  5.33s/it]
#
#
#
#
#  51%|█████     | 639/1261 [56:34<55:39,  5.37s/it]
#
#
#
#
#  51%|█████     | 640/1261 [56:39<55:19,  5.34s/it]
#
#
#
#
#  51%|█████     | 641/1261 [56:44<55:06,  5.33s/it]
#
#
#
#
#  51%|█████     | 642/1261 [56:50<55:27,  5.38s/it]
#
#
#
#
#  51%|█████     | 643/1261 [56:55<55:26,  5.38s/it]
#
#
#
#
#  51%|█████     | 644/1261 [57:00<54:59,  5.35s/it]
#
#
#
#
#  51%|█████     | 645/1261 [57:06<54:46,  5.34s/it]
#
#
#
#
#  51%|█████     | 646/1261 [57:11<54:39,  5.33s/it]
#
#
#
#
#  51%|█████▏    | 647/1261 [57:16<54:35,  5.33s/it]
#
#
#
#
#  51%|█████▏    | 648/1261 [57:22<54:22,  5.32s/it]
#
#
#
#
#  51%|█████▏    | 649/1261 [57:27<54:06,  5.30s/it]
#
#
#
#
#  52%|█████▏    | 650/1261 [57:32<54:01,  5.31s/it]
#
#
#
#
#  52%|█████▏    | 651/1261 [57:38<53:53,  5.30s/it]
#
#
#
#
#  52%|█████▏    | 652/1261 [57:43<53:40,  5.29s/it]
#
#
#
#
#  52%|█████▏    | 653/1261 [57:48<53:38,  5.29s/it]
#
#
#
#
#  52%|█████▏    | 654/1261 [57:53<53:44,  5.31s/it]
#
#
#
#
#  52%|█████▏    | 655/1261 [57:59<53:33,  5.30s/it]
#
#
#
#
#  52%|█████▏    | 656/1261 [58:04<53:27,  5.30s/it]
#
#
#
#
#  52%|█████▏    | 657/1261 [58:09<53:28,  5.31s/it]
#
#
#
#
#  52%|█████▏    | 658/1261 [58:15<53:38,  5.34s/it]
#
#
#
#
#  52%|█████▏    | 659/1261 [58:20<54:08,  5.40s/it]
#
#
#
#
#  52%|█████▏    | 660/1261 [58:26<54:49,  5.47s/it]
#
#
#
#
#  52%|█████▏    | 661/1261 [58:31<54:34,  5.46s/it]
#
#
#
#
#  52%|█████▏    | 662/1261 [58:37<54:20,  5.44s/it]
#
#
#
#
#  53%|█████▎    | 663/1261 [58:42<54:12,  5.44s/it]
#
#
#
#
#  53%|█████▎    | 664/1261 [58:48<53:47,  5.41s/it]
#
#
#
#
#  53%|█████▎    | 665/1261 [58:53<53:34,  5.39s/it]
#
#
#
#
#  53%|█████▎    | 666/1261 [58:58<53:25,  5.39s/it]
#
#
#
#
#  53%|█████▎    | 667/1261 [59:04<53:13,  5.38s/it]
#
#
#
#
#  53%|█████▎    | 668/1261 [59:09<53:24,  5.40s/it]
#
#
#
#
#  53%|█████▎    | 669/1261 [59:14<53:13,  5.39s/it]
#
#
#
#
#  53%|█████▎    | 670/1261 [59:20<53:15,  5.41s/it]
#
#
#
#
#  53%|█████▎    | 671/1261 [59:25<53:09,  5.41s/it]
#
#
#
#
#  53%|█████▎    | 672/1261 [59:31<53:01,  5.40s/it]
#
#
#
#
#  53%|█████▎    | 673/1261 [59:36<52:58,  5.41s/it]
#
#
#
#
#  53%|█████▎    | 674/1261 [59:41<52:29,  5.37s/it]
#
#
#
#
#  54%|█████▎    | 675/1261 [59:47<52:11,  5.34s/it]
#
#
#
#
#  54%|█████▎    | 676/1261 [59:52<52:03,  5.34s/it]
#
#
#
#
#  54%|█████▎    | 677/1261 [59:57<51:44,  5.32s/it]
#
#
#
#
#  54%|█████▍    | 678/1261 [1:00:02<51:10,  5.27s/it]
#
#
#
#
#  54%|█████▍    | 679/1261 [1:00:08<50:59,  5.26s/it]
#
#
#
#
#  54%|█████▍    | 680/1261 [1:00:13<50:41,  5.24s/it]
#
#
#
#
#  54%|█████▍    | 681/1261 [1:00:18<50:48,  5.26s/it]
#
#
#
#
#  54%|█████▍    | 682/1261 [1:00:23<50:25,  5.23s/it]
#  54%|█████▍    | 683/1261 [1:00:28<50:12,  5.21s/it]
#
#
#
#
#  54%|█████▍    | 684/1261 [1:00:34<51:09,  5.32s/it]
#
#
#
#
#  54%|█████▍    | 685/1261 [1:00:40<52:07,  5.43s/it]
#
#
#
#
#  54%|█████▍    | 686/1261 [1:00:45<52:33,  5.48s/it]
#
#
#
#
#  54%|█████▍    | 687/1261 [1:00:51<52:11,  5.46s/it]
#
#
#
#
#  55%|█████▍    | 688/1261 [1:00:56<51:44,  5.42s/it]
#
#
#
#
#  55%|█████▍    | 689/1261 [1:01:01<51:20,  5.39s/it]
#
#
#
#
#  55%|█████▍    | 690/1261 [1:01:07<51:00,  5.36s/it]
#
#
#
#
#  55%|█████▍    | 691/1261 [1:01:12<50:40,  5.33s/it]
#
#
#
#
#  55%|█████▍    | 692/1261 [1:01:17<50:28,  5.32s/it]
#
#
#
#
#  55%|█████▍    | 693/1261 [1:01:23<50:58,  5.39s/it]
#
#
#
#
#  55%|█████▌    | 694/1261 [1:01:28<50:48,  5.38s/it]
#
#
#
#
#  55%|█████▌    | 695/1261 [1:01:33<50:06,  5.31s/it]
#
#
#
#
#  55%|█████▌    | 696/1261 [1:01:39<49:44,  5.28s/it]
#
#
#
#
#  55%|█████▌    | 697/1261 [1:01:44<50:15,  5.35s/it]
#
#
#
#
#  55%|█████▌    | 698/1261 [1:01:49<50:09,  5.35s/it]
#
#
#
#
#  55%|█████▌    | 699/1261 [1:01:55<50:28,  5.39s/it]
#
#
#
#
#  56%|█████▌    | 700/1261 [1:02:00<50:32,  5.41s/it]
#
#
#
#
#  56%|█████▌    | 701/1261 [1:02:06<50:36,  5.42s/it]
#
#
#
#
#  56%|█████▌    | 702/1261 [1:02:11<50:37,  5.43s/it]
#
#
#
#
#  56%|█████▌    | 703/1261 [1:02:16<50:05,  5.39s/it]
#
#
#
#
#  56%|█████▌    | 704/1261 [1:02:22<49:50,  5.37s/it]
#
#
#
#
#  56%|█████▌    | 705/1261 [1:02:27<49:43,  5.37s/it]
#
#
#
#
#  56%|█████▌    | 706/1261 [1:02:32<49:21,  5.34s/it]
#
#
#
#
#  56%|█████▌    | 707/1261 [1:02:38<48:43,  5.28s/it]
#
#
#
#
#  56%|█████▌    | 708/1261 [1:02:43<48:33,  5.27s/it]
#
#
#
#
#  56%|█████▌    | 709/1261 [1:02:48<48:51,  5.31s/it]
#
#
#
#
#  56%|█████▋    | 710/1261 [1:02:54<48:41,  5.30s/it]
#
#
#
#
#  56%|█████▋    | 711/1261 [1:02:59<49:07,  5.36s/it]
#
#
#
#
#  56%|█████▋    | 712/1261 [1:03:04<49:08,  5.37s/it]
#
#
#
#
#  57%|█████▋    | 713/1261 [1:03:10<48:43,  5.34s/it]
#
#
#
#
#  57%|█████▋    | 714/1261 [1:03:15<49:11,  5.40s/it]
#
#
#
#
#  57%|█████▋    | 715/1261 [1:03:21<49:20,  5.42s/it]
#
#
#
#
#  57%|█████▋    | 716/1261 [1:03:26<48:52,  5.38s/it]
#
#
#
#
#  57%|█████▋    | 717/1261 [1:03:31<48:31,  5.35s/it]
#
#
#
#
#  57%|█████▋    | 718/1261 [1:03:37<48:16,  5.33s/it]
#
#
#
#
#  57%|█████▋    | 719/1261 [1:03:42<48:06,  5.33s/it]
#
#
#
#
#  57%|█████▋    | 720/1261 [1:03:47<48:12,  5.35s/it]
#
#
#
#
#  57%|█████▋    | 721/1261 [1:03:53<48:12,  5.36s/it]
#
#
#
#
#  57%|█████▋    | 722/1261 [1:03:58<48:06,  5.36s/it]
#
#
#
#
#  57%|█████▋    | 723/1261 [1:04:03<47:51,  5.34s/it]
#
#
#
#
#  57%|█████▋    | 724/1261 [1:04:09<47:32,  5.31s/it]
#
#
#
#
#  57%|█████▋    | 725/1261 [1:04:14<47:22,  5.30s/it]
#
#
#
#
#  58%|█████▊    | 726/1261 [1:04:19<47:13,  5.30s/it]
#
#
#
#
#  58%|█████▊    | 727/1261 [1:04:24<47:19,  5.32s/it]
#
#
#
#
#  58%|█████▊    | 728/1261 [1:04:30<47:30,  5.35s/it]
#
#
#
#
#  58%|█████▊    | 729/1261 [1:04:35<47:17,  5.33s/it]
#
#
#
#
#  58%|█████▊    | 730/1261 [1:04:41<47:13,  5.34s/it]
#
#
#
#
#  58%|█████▊    | 731/1261 [1:04:46<46:37,  5.28s/it]
#
#
#
#
#  58%|█████▊    | 732/1261 [1:04:51<46:19,  5.25s/it]
#
#
#
#
#  58%|█████▊    | 733/1261 [1:04:56<46:08,  5.24s/it]
#
#
#
#
#  58%|█████▊    | 734/1261 [1:05:01<46:01,  5.24s/it]
#
#
#
#
#  58%|█████▊    | 735/1261 [1:05:07<45:51,  5.23s/it]
#
#
#
#
#  58%|█████▊    | 736/1261 [1:05:12<45:45,  5.23s/it]
#
#
#
#
#  58%|█████▊    | 737/1261 [1:05:17<45:29,  5.21s/it]
#
#
#
#
#  59%|█████▊    | 738/1261 [1:05:22<45:10,  5.18s/it]
#
#
#
#
#  59%|█████▊    | 739/1261 [1:05:27<44:55,  5.16s/it]
#
#
#
#
#  59%|█████▊    | 740/1261 [1:05:32<44:42,  5.15s/it]
#
#
#
#
#  59%|█████▉    | 741/1261 [1:05:37<44:33,  5.14s/it]
#
#
#
#
#  59%|█████▉    | 742/1261 [1:05:43<44:30,  5.15s/it]
#
#
#
#
#  59%|█████▉    | 743/1261 [1:05:48<45:21,  5.25s/it]
#
#
#
#
#  59%|█████▉    | 744/1261 [1:05:53<45:27,  5.28s/it]
#
#
#
#
#  59%|█████▉    | 745/1261 [1:05:59<46:13,  5.37s/it]
#
#
#
#
#  59%|█████▉    | 746/1261 [1:06:04<46:24,  5.41s/it]
#
#
#
#
#  59%|█████▉    | 747/1261 [1:06:10<46:02,  5.37s/it]
#
#
#
#
#  59%|█████▉    | 748/1261 [1:06:15<45:45,  5.35s/it]
#
#
#
#
#  59%|█████▉    | 749/1261 [1:06:20<45:37,  5.35s/it]
#
#
#
#
#  59%|█████▉    | 750/1261 [1:06:26<45:31,  5.35s/it]
#
#
#
#
#  60%|█████▉    | 751/1261 [1:06:31<45:36,  5.37s/it]
#
#
#
#
#  60%|█████▉    | 752/1261 [1:06:36<45:21,  5.35s/it]
#
#
#
#
#  60%|█████▉    | 753/1261 [1:06:42<45:08,  5.33s/it]
#
#
#
#
#  60%|█████▉    | 754/1261 [1:06:47<45:19,  5.36s/it]
#
#
#
#
#  60%|█████▉    | 755/1261 [1:06:53<45:22,  5.38s/it]
#
#
#
#
#  60%|█████▉    | 756/1261 [1:06:58<45:11,  5.37s/it]
#
#
#
#
#  60%|██████    | 757/1261 [1:07:03<45:14,  5.39s/it]
#
#
#
#
#  60%|██████    | 758/1261 [1:07:09<45:09,  5.39s/it]
#
#
#
#
#  60%|██████    | 759/1261 [1:07:14<45:05,  5.39s/it]
#
#
#
#
#  60%|██████    | 760/1261 [1:07:19<44:43,  5.36s/it]
#
#
#
#
#  60%|██████    | 761/1261 [1:07:25<44:38,  5.36s/it]
#
#
#
#
#  60%|██████    | 762/1261 [1:07:30<44:30,  5.35s/it]
#
#
#
#
#  61%|██████    | 763/1261 [1:07:35<44:15,  5.33s/it]
#
#
#
#
#  61%|██████    | 764/1261 [1:07:41<44:22,  5.36s/it]
#
#
#
#
#  61%|██████    | 765/1261 [1:07:46<44:10,  5.34s/it]
#
#
#
#
#  61%|██████    | 766/1261 [1:07:52<44:32,  5.40s/it]
#
#
#
#
#  61%|██████    | 767/1261 [1:07:57<44:35,  5.42s/it]
#
#
#
#
#  61%|██████    | 768/1261 [1:08:02<44:24,  5.41s/it]
#
#
#
#
#  61%|██████    | 769/1261 [1:08:08<44:18,  5.40s/it]
#
#
#
#
#  61%|██████    | 770/1261 [1:08:13<44:12,  5.40s/it]
#
#
#
#
#  61%|██████    | 771/1261 [1:08:19<43:55,  5.38s/it]
#
#
#
#
#  61%|██████    | 772/1261 [1:08:24<43:56,  5.39s/it]
#
#
#
#
#  61%|██████▏   | 773/1261 [1:08:29<43:51,  5.39s/it]
#
#
#
#
#  61%|██████▏   | 774/1261 [1:08:35<43:46,  5.39s/it]
#
#
#
#
#  61%|██████▏   | 775/1261 [1:08:40<43:37,  5.39s/it]
#
#
#
#
#  62%|██████▏   | 776/1261 [1:08:46<44:12,  5.47s/it]
#
#
#
#
#  62%|██████▏   | 777/1261 [1:08:52<45:05,  5.59s/it]
#
#
#
#
#  62%|██████▏   | 778/1261 [1:08:57<44:52,  5.57s/it]
#
#
#
#
#  62%|██████▏   | 779/1261 [1:09:03<45:05,  5.61s/it]
#
#
#
#
#  62%|██████▏   | 780/1261 [1:09:09<45:11,  5.64s/it]
#
#
#
#
#  62%|██████▏   | 781/1261 [1:09:14<45:11,  5.65s/it]
#
#
#
#
#  62%|██████▏   | 782/1261 [1:09:20<44:25,  5.56s/it]
#
#
#
#
#  62%|██████▏   | 783/1261 [1:09:25<43:39,  5.48s/it]
#
#
#
#
#  62%|██████▏   | 784/1261 [1:09:31<43:39,  5.49s/it]
#
#
#
#
#  62%|██████▏   | 785/1261 [1:09:36<43:16,  5.45s/it]
#
#
#
#
#  62%|██████▏   | 786/1261 [1:09:41<43:05,  5.44s/it]
#
#
#
#
#  62%|██████▏   | 787/1261 [1:09:47<42:43,  5.41s/it]
#
#
#
#
#  62%|██████▏   | 788/1261 [1:09:52<42:38,  5.41s/it]
#
#
#
#
#  63%|██████▎   | 789/1261 [1:09:58<42:50,  5.45s/it]
#
#
#
#
#  63%|██████▎   | 790/1261 [1:10:03<42:15,  5.38s/it]
#
#
#
#
#  63%|██████▎   | 791/1261 [1:10:08<41:33,  5.31s/it]
#
#
#
#
#  63%|██████▎   | 792/1261 [1:10:13<40:53,  5.23s/it]
#
#
#
#
#  63%|██████▎   | 793/1261 [2:04:43<128:00:09, 984.64s/it]
#
#
#
#
#  63%|██████▎   | 794/1261 [2:04:49<89:37:46, 690.94s/it]
#
#
#
#
#  63%|██████▎   | 795/1261 [2:04:54<62:49:03, 485.29s/it]
#
#
#
#
#  63%|██████▎   | 796/1261 [2:04:59<44:05:14, 341.32s/it]
#
#
#
#
#  63%|██████▎   | 797/1261 [2:05:05<30:59:49, 240.49s/it]
#
#
#
#
#  63%|██████▎   | 798/1261 [2:05:10<21:50:54, 169.88s/it]
#
#
#
#
#  63%|██████▎   | 799/1261 [2:05:15<15:27:38, 120.47s/it]
#
#
#
#
#  63%|██████▎   | 800/1261 [2:05:20<10:59:55, 85.89s/it]
#
#
#
#
#  64%|██████▎   | 801/1261 [2:05:25<7:52:56, 61.69s/it]
#
#
#
#
#  64%|██████▎   | 802/1261 [2:05:31<5:43:22, 44.89s/it]
#
#
#
#
#  64%|██████▎   | 803/1261 [2:05:37<4:13:36, 33.22s/it]
#
#
#
#
#  64%|██████▍   | 804/1261 [2:05:43<3:10:19, 24.99s/it]
#
#
#
#
#  64%|██████▍   | 805/1261 [2:05:48<2:25:21, 19.13s/it]
#
#
#
#
#  64%|██████▍   | 806/1261 [2:05:54<1:53:40, 14.99s/it]
#
#
#
#
#  64%|██████▍   | 807/1261 [2:05:59<1:31:26, 12.08s/it]
#
#
#
#
#  64%|██████▍   | 808/1261 [2:06:04<1:15:52, 10.05s/it]
#
#
#
#
#  64%|██████▍   | 809/1261 [2:06:09<1:04:59,  8.63s/it]
#
#
#
#
#  64%|██████▍   | 810/1261 [2:06:15<57:31,  7.65s/it]
#
#
#
#
#  64%|██████▍   | 811/1261 [2:06:20<52:09,  6.95s/it]
#
#
#
#
#  64%|██████▍   | 812/1261 [2:06:25<48:19,  6.46s/it]
#
#
#
#
#  64%|██████▍   | 813/1261 [2:06:31<45:35,  6.11s/it]
#
#
#
#
#  65%|██████▍   | 814/1261 [2:06:36<43:38,  5.86s/it]
#
#
#
#
#  65%|██████▍   | 815/1261 [2:06:41<42:18,  5.69s/it]
#
#
#
#
#  65%|██████▍   | 816/1261 [2:06:47<41:22,  5.58s/it]
#
#
#
#
#  65%|██████▍   | 817/1261 [2:06:52<40:44,  5.51s/it]
#
#
#
#
#  65%|██████▍   | 818/1261 [2:06:57<40:14,  5.45s/it]
#
#
#
#
#  65%|██████▍   | 819/1261 [2:07:03<39:49,  5.41s/it]
#
#
#
#
#  65%|██████▌   | 820/1261 [2:07:08<39:29,  5.37s/it]
#
#
#
#
#  65%|██████▌   | 821/1261 [2:07:13<39:19,  5.36s/it]
#
#
#
#
#  65%|██████▌   | 822/1261 [2:07:19<39:34,  5.41s/it]
#
#
#
#
#  65%|██████▌   | 823/1261 [2:07:24<39:22,  5.39s/it]
#
#
#
#
#  65%|██████▌   | 824/1261 [2:07:29<39:09,  5.38s/it]
#
#
#
#
#  65%|██████▌   | 825/1261 [2:07:35<39:09,  5.39s/it]
#
#
#
#
#  66%|██████▌   | 826/1261 [2:07:40<39:10,  5.40s/it]
#
#
#
#
#  66%|██████▌   | 827/1261 [2:07:46<39:04,  5.40s/it]
#
#
#
#
#  66%|██████▌   | 828/1261 [2:07:51<39:00,  5.41s/it]
#
#
#
#
#  66%|██████▌   | 829/1261 [2:07:57<38:49,  5.39s/it]
#
#
#
#
#  66%|██████▌   | 830/1261 [2:08:02<38:36,  5.37s/it]
#
#
#
#
#  66%|██████▌   | 831/1261 [2:08:07<38:24,  5.36s/it]
#
#
#
#
#  66%|██████▌   | 832/1261 [2:08:13<38:16,  5.35s/it]
#
#
#
#
#  66%|██████▌   | 833/1261 [2:08:18<38:14,  5.36s/it]
#
#
#
#
#  66%|██████▌   | 834/1261 [2:08:23<38:06,  5.36s/it]
#
#
#
#
#  66%|██████▌   | 835/1261 [2:08:29<38:01,  5.36s/it]
#
#
#
#
#  66%|██████▋   | 836/1261 [2:08:34<37:45,  5.33s/it]
#
#
#
#
#  66%|██████▋   | 837/1261 [2:08:39<37:40,  5.33s/it]
#
#
#
#
#  66%|██████▋   | 838/1261 [2:08:45<37:36,  5.33s/it]
#
#
#
#
#  67%|██████▋   | 839/1261 [2:08:50<37:27,  5.33s/it]
#
#
#
#
#  67%|██████▋   | 840/1261 [2:08:55<37:21,  5.32s/it]
#
#
#
#
#  67%|██████▋   | 841/1261 [2:09:00<37:11,  5.31s/it]
#
#
#
#
#  67%|██████▋   | 842/1261 [2:09:06<37:05,  5.31s/it]
#
#
#
#
#  67%|██████▋   | 843/1261 [2:09:11<37:07,  5.33s/it]
#
#
#
#
#  67%|██████▋   | 844/1261 [2:09:16<37:04,  5.33s/it]
#
#
#
#
# ...
#
#
#
#
#  78%|███████▊  | 988/1261 [2:22:11<24:38,  5.41s/it]
#
#
#
#
#  78%|███████▊  | 989/1261 [2:22:16<24:34,  5.42s/it]
#
#
#
#
#  79%|███████▊  | 990/1261 [2:22:21<24:25,  5.41s/it]
#
#
#
#
#  79%|███████▊  | 991/1261 [2:22:27<24:17,  5.40s/it]
#
#
#
#
#  79%|███████▊  | 992/1261 [2:22:32<24:04,  5.37s/it]
#
#
#
#
#  79%|███████▊  | 993/1261 [2:22:37<23:54,  5.35s/it]
#
#
#
#
#  79%|███████▉  | 994/1261 [2:22:43<23:43,  5.33s/it]
#
#
#
#
#  79%|███████▉  | 995/1261 [2:22:48<23:39,  5.34s/it]
#
#
#
#
#  79%|███████▉  | 996/1261 [2:22:53<23:36,  5.34s/it]
#
#
#
#
#  79%|███████▉  | 997/1261 [2:22:59<23:30,  5.34s/it]
#
#
#
#
#  79%|███████▉  | 998/1261 [2:23:04<23:25,  5.34s/it]
#
#
#
#
#  79%|███████▉  | 999/1261 [2:23:09<23:25,  5.37s/it]
#
#
#
#
#  79%|███████▉  | 1000/1261 [2:23:19<28:33,  6.56s/it]
#
#
#
#
#  79%|███████▉  | 1001/1261 [2:23:24<26:58,  6.22s/it]
#
#
#
#
#  79%|███████▉  | 1002/1261 [2:23:30<25:56,  6.01s/it]
#
#
#
#
#  80%|███████▉  | 1003/1261 [2:23:35<24:59,  5.81s/it]
#
#
#
#
#  80%|███████▉  | 1004/1261 [2:23:40<24:17,  5.67s/it]
#
#
#
#
#  80%|███████▉  | 1005/1261 [2:23:46<23:48,  5.58s/it]
#
#
#
#
#  80%|███████▉  | 1006/1261 [2:23:51<23:26,  5.52s/it]
#
#
#
#
#  80%|███████▉  | 1007/1261 [2:23:56<23:08,  5.46s/it]
#
#
#
#
#  80%|███████▉  | 1008/1261 [2:24:02<22:53,  5.43s/it]
#
#
#
#
#  80%|████████  | 1009/1261 [2:24:07<22:45,  5.42s/it]
#
#
#
#
#  80%|████████  | 1010/1261 [2:24:13<22:35,  5.40s/it]
#
#
#
#
#  80%|████████  | 1011/1261 [2:24:18<22:34,  5.42s/it]
#
#
#
#
#  80%|████████  | 1012/1261 [2:24:23<22:28,  5.41s/it]
#
#
#
#
#  80%|████████  | 1013/1261 [2:24:29<22:19,  5.40s/it]
#
#
#
#
#  80%|████████  | 1014/1261 [2:24:34<22:11,  5.39s/it]
#
#
#
#
#  80%|████████  | 1015/1261 [2:24:40<22:02,  5.38s/it]
#
#
#
#
#  81%|████████  | 1016/1261 [2:24:45<21:54,  5.37s/it]
#
#
#
#
#  81%|████████  | 1017/1261 [2:24:50<21:49,  5.37s/it]
#
#
#
#
#  81%|████████  | 1018/1261 [2:24:56<21:42,  5.36s/it]
#
#
#
#
#  81%|████████  | 1019/1261 [2:25:01<21:37,  5.36s/it]
#
#
#
#
#  81%|████████  | 1020/1261 [2:25:06<21:37,  5.38s/it]
#
#
#
#
#  81%|████████  | 1021/1261 [2:25:12<21:29,  5.37s/it]
#
#
#
#
#  81%|████████  | 1022/1261 [2:25:17<21:24,  5.38s/it]
#
#
#
#
#  81%|████████  | 1023/1261 [2:25:23<21:22,  5.39s/it]
#
#
#
#
#  81%|████████  | 1024/1261 [2:25:28<21:14,  5.38s/it]
#
#
#
#
#  81%|████████▏ | 1025/1261 [2:25:33<21:09,  5.38s/it]
#
#
#
#
#  81%|████████▏ | 1026/1261 [2:25:39<21:23,  5.46s/it]
#
#
#
#
#  81%|████████▏ | 1027/1261 [2:25:44<21:24,  5.49s/it]
#
#
#
#
#  82%|████████▏ | 1028/1261 [2:25:50<21:15,  5.47s/it]
#
#
#
#
#  82%|████████▏ | 1029/1261 [2:25:55<21:03,  5.45s/it]
#
#
#
#
#  82%|████████▏ | 1030/1261 [2:26:01<20:53,  5.42s/it]
#
#
#
#
#  82%|████████▏ | 1031/1261 [2:26:06<20:46,  5.42s/it]
#
#
#
#
#  82%|████████▏ | 1032/1261 [2:26:11<20:36,  5.40s/it]
#
#
#
#
#  82%|████████▏ | 1033/1261 [2:26:17<20:36,  5.42s/it]
#
#
#
#
#  82%|████████▏ | 1034/1261 [2:26:22<20:34,  5.44s/it]
#
#
#
#
#  82%|████████▏ | 1035/1261 [2:26:28<20:25,  5.42s/it]
#
#
#
#
#  82%|████████▏ | 1036/1261 [2:26:33<20:14,  5.40s/it]
#
#
#
#
#  82%|████████▏ | 1037/1261 [2:26:38<20:09,  5.40s/it]
#
#
#
#
#  82%|████████▏ | 1038/1261 [2:26:44<20:01,  5.39s/it]
#
#
#
#
#  82%|████████▏ | 1039/1261 [2:26:49<19:57,  5.39s/it]
#
#
#
#
#  82%|████████▏ | 1040/1261 [2:26:55<19:52,  5.40s/it]
#
#
#
#
#  83%|████████▎ | 1041/1261 [2:27:00<19:48,  5.40s/it]
#
#
#
#
#  83%|████████▎ | 1042/1261 [2:27:05<19:41,  5.39s/it]
#
#
#
#
#  83%|████████▎ | 1043/1261 [2:27:11<19:34,  5.39s/it]
#
#
#
#
#  83%|████████▎ | 1044/1261 [2:27:16<19:28,  5.39s/it]
#
#
#
#
#  83%|████████▎ | 1045/1261 [2:27:22<19:21,  5.38s/it]
#
#
#
#
#  83%|████████▎ | 1046/1261 [2:27:27<19:18,  5.39s/it]
#
#
#
#
#  83%|████████▎ | 1047/1261 [2:27:32<19:12,  5.38s/it]
#
#
#
#
#  83%|████████▎ | 1048/1261 [2:27:38<19:07,  5.39s/it]
#
#
#
#
#  83%|████████▎ | 1049/1261 [2:27:43<18:59,  5.38s/it]
#
#
#
#
#  83%|████████▎ | 1050/1261 [2:27:48<18:53,  5.37s/it]
#
#
#
#
#  83%|████████▎ | 1051/1261 [2:27:54<18:47,  5.37s/it]
#
#
#
#
#  83%|████████▎ | 1052/1261 [2:27:59<18:41,  5.36s/it]
#
#
#
#
#  84%|████████▎ | 1053/1261 [2:28:05<18:36,  5.37s/it]
#
#
#
#
#  84%|████████▎ | 1054/1261 [2:28:10<18:33,  5.38s/it]
#
#
#
#
#  84%|████████▎ | 1055/1261 [2:28:15<18:28,  5.38s/it]
#
#
#
#
#  84%|████████▎ | 1056/1261 [2:28:21<18:28,  5.41s/it]
#
#
#
#
#  84%|████████▍ | 1057/1261 [2:28:26<18:29,  5.44s/it]
#
#
#
#
#  84%|████████▍ | 1058/1261 [2:28:32<18:19,  5.42s/it]
#
#
#
#
#  84%|████████▍ | 1059/1261 [2:28:37<18:11,  5.40s/it]
#
#
#
#
#  84%|████████▍ | 1060/1261 [2:28:42<18:02,  5.39s/it]
#
#
#
#
#  84%|████████▍ | 1061/1261 [2:28:48<17:57,  5.39s/it]
#
#
#
#
#  84%|████████▍ | 1062/1261 [2:28:53<17:49,  5.38s/it]
#
#
#
#
#  84%|████████▍ | 1063/1261 [2:28:59<17:43,  5.37s/it]
#
#
#
#
#  84%|████████▍ | 1064/1261 [2:29:04<17:39,  5.38s/it]
#
#
#
#
#  84%|████████▍ | 1065/1261 [2:29:09<17:32,  5.37s/it]
#
#
#
#
#  85%|████████▍ | 1066/1261 [2:29:15<17:26,  5.36s/it]
#
#
#
#
#  85%|████████▍ | 1067/1261 [2:29:20<17:23,  5.38s/it]
#
#
#
#
#  85%|████████▍ | 1068/1261 [2:29:25<17:17,  5.38s/it]
#
#
#
#
#  85%|████████▍ | 1069/1261 [2:29:31<17:11,  5.37s/it]
#
#
#
#
#  85%|████████▍ | 1070/1261 [2:29:36<17:07,  5.38s/it]
#
#
#
#
#  85%|████████▍ | 1071/1261 [2:29:42<17:04,  5.39s/it]
#
#
#
#
#  85%|████████▌ | 1072/1261 [2:29:47<16:59,  5.39s/it]
#
#
#
#
#  85%|████████▌ | 1073/1261 [2:29:52<16:53,  5.39s/it]
#
#
#
#
#  85%|████████▌ | 1074/1261 [2:29:58<16:47,  5.39s/it]
#
#
#
#
#  85%|████████▌ | 1075/1261 [2:30:03<16:41,  5.38s/it]
#
#
#
#
#  85%|████████▌ | 1076/1261 [2:30:09<16:44,  5.43s/it]
#
#
#
#
#  85%|████████▌ | 1077/1261 [2:30:14<16:37,  5.42s/it]
#
#
#
#
#  85%|████████▌ | 1078/1261 [2:30:20<16:41,  5.47s/it]
#
#
#
#
#  86%|████████▌ | 1079/1261 [2:30:25<16:33,  5.46s/it]
#
#
#
#
#  86%|████████▌ | 1080/1261 [2:30:30<16:24,  5.44s/it]
#
#
#
#
#  86%|████████▌ | 1081/1261 [2:30:36<16:16,  5.43s/it]
#
#
#
#
#  86%|████████▌ | 1082/1261 [2:30:41<16:10,  5.42s/it]
#
#
#
#
#  86%|████████▌ | 1083/1261 [2:30:47<16:04,  5.42s/it]
#
#
#
#
#  86%|████████▌ | 1084/1261 [2:30:52<15:59,  5.42s/it]
#
#
#
#
#  86%|████████▌ | 1085/1261 [2:30:57<15:51,  5.41s/it]
#
#
#
#
#  86%|████████▌ | 1086/1261 [2:31:03<15:44,  5.40s/it]
#
#
#
#
#  86%|████████▌ | 1087/1261 [2:31:08<15:39,  5.40s/it]
#
#
#
#
#  86%|████████▋ | 1088/1261 [2:31:14<15:34,  5.40s/it]
#
#
#
#
#  86%|████████▋ | 1089/1261 [2:31:19<15:31,  5.42s/it]
#
#
#
#
#  86%|████████▋ | 1090/1261 [2:31:25<15:28,  5.43s/it]
#
#
#
#
#  87%|████████▋ | 1091/1261 [2:31:30<15:20,  5.41s/it]
#
#
#
#
#  87%|████████▋ | 1092/1261 [2:31:35<15:12,  5.40s/it]
#
#
#
#
#  87%|████████▋ | 1093/1261 [2:31:41<15:04,  5.38s/it]
#
#
#
#
#  87%|████████▋ | 1094/1261 [2:31:46<15:05,  5.42s/it]
#
#
#
#
#  87%|████████▋ | 1095/1261 [2:31:52<15:01,  5.43s/it]
#
#
#
#
#  87%|████████▋ | 1096/1261 [2:31:57<14:56,  5.43s/it]
#
#
#
#
#  87%|████████▋ | 1097/1261 [2:32:02<14:49,  5.43s/it]
#
#
#
#
#  87%|████████▋ | 1098/1261 [2:32:08<14:43,  5.42s/it]
#
#
#
#
#  87%|████████▋ | 1099/1261 [2:32:13<14:34,  5.40s/it]
#
#
#
#
#  87%|████████▋ | 1100/1261 [2:32:19<14:30,  5.41s/it]
#
#
#
#
#  87%|████████▋ | 1101/1261 [2:32:24<14:25,  5.41s/it]
#
#
#
#
#  87%|████████▋ | 1102/1261 [2:32:29<14:20,  5.41s/it]
#
#
#
#
#  87%|████████▋ | 1103/1261 [2:32:35<14:12,  5.39s/it]
#
#
#
#
#  88%|████████▊ | 1104/1261 [2:32:40<14:06,  5.39s/it]
#
#
#
#
#  88%|████████▊ | 1105/1261 [2:32:46<14:01,  5.40s/it]
#
#
#
#
#  88%|████████▊ | 1106/1261 [2:32:51<13:58,  5.41s/it]
#
#
#
#
#  88%|████████▊ | 1107/1261 [2:32:56<13:50,  5.39s/it]
#
#
#
#
#  88%|████████▊ | 1108/1261 [2:33:02<13:43,  5.39s/it]
#
#
#
#
#  88%|████████▊ | 1109/1261 [2:33:07<13:38,  5.38s/it]
#
#
#
#
#  88%|████████▊ | 1110/1261 [2:33:13<13:34,  5.39s/it]
#
#
#
#
#  88%|████████▊ | 1111/1261 [2:33:18<13:29,  5.40s/it]
#
#
#
#
#  88%|████████▊ | 1112/1261 [2:33:23<13:26,  5.41s/it]
#
#
#
#
#  88%|████████▊ | 1113/1261 [2:33:29<13:20,  5.41s/it]
#
#
#
#
#  88%|████████▊ | 1114/1261 [2:33:34<13:18,  5.43s/it]
#
#
#
#
#  88%|████████▊ | 1115/1261 [2:33:40<13:11,  5.42s/it]
#
#
#
#
#  89%|████████▊ | 1116/1261 [2:33:45<13:02,  5.40s/it]
#
#
#
#
#  89%|████████▊ | 1117/1261 [2:33:50<12:57,  5.40s/it]
#
#
#
#
#  89%|████████▊ | 1118/1261 [2:33:56<12:52,  5.40s/it]
#
#
#
#
#  89%|████████▊ | 1119/1261 [2:34:01<12:48,  5.41s/it]
#
#
#
#
#  89%|████████▉ | 1120/1261 [2:34:07<12:42,  5.41s/it]
#
#
#
#
#  89%|████████▉ | 1121/1261 [2:34:12<12:35,  5.40s/it]
#
#
#
#
#  89%|████████▉ | 1122/1261 [2:34:18<12:30,  5.40s/it]
#
#
#
#
#  89%|████████▉ | 1123/1261 [2:34:23<12:28,  5.42s/it]
#
#
#
#
#  89%|████████▉ | 1124/1261 [2:34:28<12:21,  5.41s/it]
#
#
#
#
#  89%|████████▉ | 1125/1261 [2:34:34<12:20,  5.44s/it]
#
#
#
#
#  89%|████████▉ | 1126/1261 [2:34:39<12:14,  5.44s/it]
#
#
#
#
#  89%|████████▉ | 1127/1261 [2:34:45<12:07,  5.43s/it]
#
#
#
#
#  89%|████████▉ | 1128/1261 [2:34:50<12:04,  5.45s/it]
#
#
#
#
#  90%|████████▉ | 1129/1261 [2:34:56<11:58,  5.44s/it]
#
#
#
#
#  90%|████████▉ | 1130/1261 [2:35:01<11:51,  5.43s/it]
#
#
#
#
#  90%|████████▉ | 1131/1261 [2:35:07<11:47,  5.44s/it]
#
#
#
#
#  90%|████████▉ | 1132/1261 [2:35:12<11:42,  5.44s/it]
#
#
#
#
#  90%|████████▉ | 1133/1261 [2:35:17<11:36,  5.44s/it]
#  90%|████████▉ | 1134/1261 [2:35:23<11:28,  5.42s/it]
#
#
#
#
#  90%|█████████ | 1135/1261 [2:35:28<11:20,  5.40s/it]
#
#
#
#
#  90%|█████████ | 1136/1261 [2:35:34<11:18,  5.42s/it]
#
#
#
#
#  90%|█████████ | 1137/1261 [2:35:39<11:13,  5.43s/it]
#
#
#
#
#  90%|█████████ | 1138/1261 [2:35:44<11:06,  5.42s/it]
#
#
#
#
#  90%|█████████ | 1139/1261 [2:35:50<11:00,  5.41s/it]
#
#
#
#
#  90%|█████████ | 1140/1261 [2:35:55<10:54,  5.41s/it]
#
#
#
#
#  90%|█████████ | 1141/1261 [2:36:01<10:47,  5.40s/it]
#
#
#
#
#  91%|█████████ | 1142/1261 [2:36:06<10:42,  5.40s/it]
#
#
#
#
#  91%|█████████ | 1143/1261 [2:36:11<10:35,  5.38s/it]
#
#
#
#
#  91%|█████████ | 1144/1261 [2:36:17<10:28,  5.37s/it]
#
#
#
#
#  91%|█████████ | 1145/1261 [2:36:22<10:24,  5.38s/it]
#
#
#
#
#  91%|█████████ | 1146/1261 [2:36:28<10:19,  5.39s/it]
#
#
#
#
#  91%|█████████ | 1147/1261 [2:36:33<10:10,  5.35s/it]
#
#
#
#
#  91%|█████████ | 1148/1261 [2:36:38<10:04,  5.35s/it]
#
#
#
#
#  91%|█████████ | 1149/1261 [2:36:44<09:59,  5.36s/it]
#
#
#
#
#  91%|█████████ | 1150/1261 [2:36:49<09:53,  5.34s/it]
#
#
#
#
#  91%|█████████▏| 1151/1261 [2:36:54<09:47,  5.34s/it]
#
#
#
#
#  91%|█████████▏| 1152/1261 [2:36:59<09:41,  5.34s/it]
#
#
#
#
#  91%|█████████▏| 1153/1261 [2:37:05<09:34,  5.32s/it]
#
#
#
#
#  92%|█████████▏| 1154/1261 [2:37:10<09:31,  5.34s/it]
#
#
#
#
#  92%|█████████▏| 1155/1261 [2:37:15<09:24,  5.33s/it]
#
#
#
#
#  92%|█████████▏| 1156/1261 [2:37:21<09:19,  5.32s/it]
#
#
#
#
#  92%|█████████▏| 1157/1261 [2:37:26<09:13,  5.33s/it]
#
#
#
#
#  92%|█████████▏| 1158/1261 [2:37:31<09:08,  5.32s/it]
#
#
#
#
#  92%|█████████▏| 1159/1261 [2:37:37<09:02,  5.32s/it]
#
#
#
#
#  92%|█████████▏| 1160/1261 [2:37:42<08:57,  5.32s/it]
#
#
#
#
#  92%|█████████▏| 1161/1261 [2:37:47<08:50,  5.31s/it]
#
#
#
#
#  92%|█████████▏| 1162/1261 [2:37:53<08:45,  5.31s/it]
#
#
#
#
#  92%|█████████▏| 1163/1261 [2:37:58<08:41,  5.32s/it]
#
#
#
#
#  92%|█████████▏| 1164/1261 [2:38:03<08:35,  5.31s/it]
#
#
#
#
#  92%|█████████▏| 1165/1261 [2:38:09<08:29,  5.31s/it]
#
#
#
#
#  92%|█████████▏| 1166/1261 [2:38:14<08:26,  5.33s/it]
#
#
#
#
#  93%|█████████▎| 1167/1261 [2:38:19<08:23,  5.36s/it]
#
#
#
#
#  93%|█████████▎| 1168/1261 [2:38:25<08:17,  5.35s/it]
#
#
#
#
#  93%|█████████▎| 1169/1261 [2:38:30<08:11,  5.34s/it]
#
#
#
#
#  93%|█████████▎| 1170/1261 [2:38:35<08:05,  5.34s/it]
#
#
#
#
#  93%|█████████▎| 1171/1261 [2:38:41<07:59,  5.32s/it]
#
#
#
#
#  93%|█████████▎| 1172/1261 [2:38:46<07:53,  5.31s/it]
#
#
#
#
#  93%|█████████▎| 1173/1261 [2:38:51<07:47,  5.31s/it]
#
#
#
#
#  93%|█████████▎| 1174/1261 [2:38:57<07:41,  5.31s/it]
#
#
#
#
#  93%|█████████▎| 1175/1261 [2:39:02<07:36,  5.31s/it]
#
#
#
#
#  93%|█████████▎| 1176/1261 [2:39:07<07:31,  5.31s/it]
#
#
#
#
#  93%|█████████▎| 1177/1261 [2:39:13<07:26,  5.32s/it]
#
#
#
#
#  93%|█████████▎| 1178/1261 [2:39:18<07:20,  5.31s/it]
#
#
#
#
#  93%|█████████▎| 1179/1261 [2:39:23<07:14,  5.30s/it]
#
#
#
#
#  94%|█████████▎| 1180/1261 [2:39:28<07:10,  5.31s/it]
#
#
#
#
#  94%|█████████▎| 1181/1261 [2:39:34<07:05,  5.32s/it]
#
#
#
#
#  94%|█████████▎| 1182/1261 [2:39:39<06:59,  5.31s/it]
#
#
#
#
#  94%|█████████▍| 1183/1261 [2:39:44<06:56,  5.33s/it]
#
#
#
#
#  94%|█████████▍| 1184/1261 [2:39:50<06:50,  5.34s/it]
#
#
#
#
#  94%|█████████▍| 1185/1261 [2:39:55<06:44,  5.32s/it]
#
#
#
#
#  94%|█████████▍| 1186/1261 [2:40:00<06:38,  5.31s/it]
#
#
#
#
#  94%|█████████▍| 1187/1261 [2:40:06<06:33,  5.32s/it]
#
#
#
#
#  94%|█████████▍| 1188/1261 [2:40:11<06:27,  5.31s/it]
#
#
#
#
#  94%|█████████▍| 1189/1261 [2:40:16<06:23,  5.32s/it]
#
#
#
#
#  94%|█████████▍| 1190/1261 [2:40:22<06:17,  5.31s/it]
#
#
#
#
#  94%|█████████▍| 1191/1261 [2:40:27<06:11,  5.31s/it]
#
#
#
#
#  95%|█████████▍| 1192/1261 [2:40:32<06:06,  5.31s/it]
#
#
#
#
#  95%|█████████▍| 1193/1261 [2:40:38<06:01,  5.32s/it]
#
#
#
#
#  95%|█████████▍| 1194/1261 [2:40:43<05:55,  5.31s/it]
#
#
#
#
#  95%|█████████▍| 1195/1261 [2:40:48<05:50,  5.30s/it]
#
#
#
#
#  95%|█████████▍| 1196/1261 [2:40:53<05:45,  5.31s/it]
#
#
#
#
#  95%|█████████▍| 1197/1261 [2:40:59<05:39,  5.31s/it]
#
#
#
#
#  95%|█████████▌| 1198/1261 [2:41:04<05:34,  5.31s/it]
#
#
#
#
#  95%|█████████▌| 1199/1261 [2:41:09<05:29,  5.31s/it]
#
#
#
#
#  95%|█████████▌| 1200/1261 [2:41:15<05:23,  5.31s/it]
#
#
#
#
#  95%|█████████▌| 1201/1261 [2:41:20<05:18,  5.31s/it]
#
#
#
#
#  95%|█████████▌| 1202/1261 [2:41:25<05:13,  5.32s/it]
#
#
#
#
#  95%|█████████▌| 1203/1261 [2:41:31<05:08,  5.32s/it]
#
#
#
#
#  95%|█████████▌| 1204/1261 [2:41:36<05:03,  5.32s/it]
#
#
#
#
#  96%|█████████▌| 1205/1261 [2:41:41<04:57,  5.32s/it]
#
#
#
#
#  96%|█████████▌| 1206/1261 [2:41:47<04:52,  5.32s/it]
#
#
#
#
#  96%|█████████▌| 1207/1261 [2:41:52<04:47,  5.33s/it]
#
#
#
#
#  96%|█████████▌| 1208/1261 [2:41:57<04:42,  5.32s/it]
#
#
#
#
#  96%|█████████▌| 1209/1261 [2:42:03<04:37,  5.34s/it]
#
#
#
#
#  96%|█████████▌| 1210/1261 [2:42:08<04:31,  5.33s/it]
#
#
#
#
#  96%|█████████▌| 1211/1261 [2:42:13<04:27,  5.36s/it]
#
#
#
#
#  96%|█████████▌| 1212/1261 [2:42:19<04:23,  5.37s/it]
#
#
#
#
#  96%|█████████▌| 1213/1261 [2:42:24<04:16,  5.35s/it]
#
#
#
#
#  96%|█████████▋| 1214/1261 [2:42:29<04:10,  5.33s/it]
#
#
#
#
#  96%|█████████▋| 1215/1261 [2:42:35<04:04,  5.32s/it]
#
#
#
#
#  96%|█████████▋| 1216/1261 [2:42:40<03:59,  5.31s/it]
#
#
#
#
#  97%|█████████▋| 1217/1261 [2:42:45<03:53,  5.31s/it]
#
#
#
#
#  97%|█████████▋| 1218/1261 [2:42:51<03:48,  5.32s/it]
#
#
#
#
#  97%|█████████▋| 1219/1261 [2:42:56<03:43,  5.32s/it]
#
#
#
#
#  97%|█████████▋| 1220/1261 [2:43:01<03:37,  5.31s/it]
#
#
#
#
#  97%|█████████▋| 1221/1261 [2:43:07<03:32,  5.32s/it]
#
#
#
#
#  97%|█████████▋| 1222/1261 [2:43:12<03:27,  5.33s/it]
#
#
#
#
#  97%|█████████▋| 1223/1261 [2:43:17<03:21,  5.31s/it]
#
#
#
#
#  97%|█████████▋| 1224/1261 [2:43:23<03:17,  5.35s/it]
#
#
#
#
#  97%|█████████▋| 1225/1261 [2:43:28<03:11,  5.33s/it]
#
#
#
#
#  97%|█████████▋| 1226/1261 [2:43:33<03:06,  5.33s/it]
#
#
#
#
#  97%|█████████▋| 1227/1261 [2:43:39<03:00,  5.32s/it]
#
#
#
#
#  97%|█████████▋| 1228/1261 [2:43:44<02:55,  5.31s/it]
#
#
#
#
#  97%|█████████▋| 1229/1261 [2:43:49<02:50,  5.32s/it]
#
#
#
#
#  98%|█████████▊| 1230/1261 [2:43:54<02:44,  5.32s/it]
#
#
#
#
#  98%|█████████▊| 1231/1261 [2:44:00<02:39,  5.32s/it]
#
#
#
#
#  98%|█████████▊| 1232/1261 [2:44:05<02:34,  5.34s/it]
#
#
#
#
#  98%|█████████▊| 1233/1261 [2:44:11<02:30,  5.38s/it]
#
#
#
#
#  98%|█████████▊| 1234/1261 [2:44:16<02:24,  5.37s/it]
#
#
#
#
#  98%|█████████▊| 1235/1261 [2:44:21<02:19,  5.37s/it]
#
#
#
#
#  98%|█████████▊| 1236/1261 [2:44:27<02:13,  5.33s/it]
#
#
#
#
#  98%|█████████▊| 1237/1261 [2:44:32<02:07,  5.32s/it]
#
#
#
#
#  98%|█████████▊| 1238/1261 [2:44:37<02:02,  5.33s/it]
#
#
#
#
#  98%|█████████▊| 1239/1261 [2:44:43<01:57,  5.32s/it]
#
#
#
#
#  98%|█████████▊| 1240/1261 [2:44:48<01:51,  5.31s/it]
#
#
#
#
#  98%|█████████▊| 1241/1261 [2:44:53<01:46,  5.33s/it]
#
#
#
#
#  98%|█████████▊| 1242/1261 [2:44:58<01:40,  5.32s/it]
#
#
#
#
#  99%|█████████▊| 1243/1261 [2:45:04<01:35,  5.31s/it]
#
#
#
#
#  99%|█████████▊| 1244/1261 [2:45:09<01:30,  5.31s/it]
#
#
#
#
#  99%|█████████▊| 1245/1261 [2:45:14<01:25,  5.33s/it]
#
#
#
#
#  99%|█████████▉| 1246/1261 [2:45:20<01:19,  5.32s/it]
#
#
#
#
#  99%|█████████▉| 1247/1261 [2:45:25<01:14,  5.32s/it]
#
#
#
#
#  99%|█████████▉| 1248/1261 [2:45:30<01:09,  5.31s/it]
#
#
#
#
#  99%|█████████▉| 1249/1261 [2:45:36<01:03,  5.32s/it]
#
#
#
#
#  99%|█████████▉| 1250/1261 [2:45:41<00:58,  5.32s/it]
#
#
#
#
#  99%|█████████▉| 1251/1261 [2:45:46<00:53,  5.32s/it]
#
#
#
#
#  99%|█████████▉| 1252/1261 [2:45:52<00:47,  5.30s/it]
#
#
#
#
#  99%|█████████▉| 1253/1261 [2:45:57<00:42,  5.31s/it]
#
#
#
#
#  99%|█████████▉| 1254/1261 [2:46:02<00:37,  5.31s/it]
#
#
#
#
# 100%|█████████▉| 1255/1261 [2:46:08<00:31,  5.31s/it]
#
#
#
#
# 100%|█████████▉| 1256/1261 [2:46:13<00:26,  5.31s/it]
#
#
#
#
# 100%|█████████▉| 1257/1261 [2:46:18<00:21,  5.34s/it]
#
#
#
#
# 100%|█████████▉| 1258/1261 [2:46:24<00:15,  5.33s/it]
#
#
#
#
# 100%|█████████▉| 1259/1261 [2:46:29<00:10,  5.32s/it]
#
#
#
#
# 100%|█████████▉| 1260/1261 [2:46:34<00:05,  5.32s/it]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_video_ouput.mp4
#
# CPU times: user 1h 53min 35s, sys: 55.8 s, total: 1h 54min 31s
# Wall time: 2h 46min 35s
